# %% [markdown]
# # Data Preparation for SPOC

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import datetime
import pathlib
import pandas as pd
from lxml import etree
import spacy
from spacy_lookup import Entity
papers_tei = pathlib.Path("/Users/jpnelson/Google Drive/Shared drives/SUL AI 2020-2021/Project - Species Occurrences/papers_tei")

# %% [markdown]
# ## Extracting Full-Text from TEI XML
# [GROBID](https://grobid.readthedocs.io/en/latest/) extracts the full-text from the PDFs and saves the result in a
# [TEI](https://tei-c.org/) XML document.

# %% [markdown]
# ## WorMS Marine Species Dataframe

# %%
taxon = pd.read_csv('/Users/jpnelson/Google Drive/Shared drives/SUL AI 2020-2021/Project - Species Occurrences/WoRMS_marineSpecies/taxon.txt', sep="\t")

# %%
species = taxon[['taxonID', 'scientificName', 'references']]
species = species.rename(columns={"references": "URL"})

# %%
species.to_json("../data/species.json")

# %% [markdown]
# ## Location DataFrame

# %%
ca_locations = pd.read_csv('/Users/jpnelson/Google Drive/Shared drives/SUL AI 2020-2021/Project - Species Occurrences/data/NamedPlaces_CA.csv')

# %%
or_locations = pd.read_csv('/Users/jpnelson/Google Drive/Shared drives/SUL AI 2020-2021/Project - Species Occurrences/data/NamedPlaces_OR.csv')

# %%
wa_locations = pd.read_csv('/Users/jpnelson/Google Drive/Shared drives/SUL AI 2020-2021/Project - Species Occurrences/data/NamedPlaces_WA.csv')

# %%
locations = pd.concat([ca_locations, or_locations, wa_locations], ignore_index=True)

# %%
locations = locations[['FEATURE_ID', 'FEATURE_NAME', 'STATE_ALPHA', 'PRIM_LONG_DEC', 'PRIM_LAT_DEC']]
locations = locations.rename(columns={'STATE_ALPHA': 'STATE', 
                                      'PRIM_LONG_DEC': 'LONGITUDE', 
                                      'PRIM_LAT_DEC': 'LATITUDE'})

# %%
locations.to_json("../data/locations.json")

# %%
locations_dict = dict(zip(locations.FEATURE_ID, locations.FEATURE_NAME))

# %% [markdown]
# ## Habitat DataFrame

# %%
import json
habitats = []
with open("/Users/jpnelson/Google Drive/Shared drives/SUL AI 2020-2021/Project - Species Occurrences/data/habitats.jsonl") as fo:
    for row in fo.readlines():
        line = json.loads(row)
        habitats.append(line.get('pattern'))
habitats = pd.DataFrame(habitats, columns=['Habitat'])

# %%
habitats.to_json("../data/habitats.json")

# %% [markdown]
# ## Construct spaCy Pipeline
# Create a spaCy nlp pipeline from the existing [en_core_web_md](https://spacy.io/models/en#en_core_web_md) English pipeline and then create a new spaCy Entity Ruler.

# %%
nlp = spacy.load('en_core_web_md')
ruler = nlp.add_pipe("entity_ruler", config={"validate": True})

# %% [markdown]
# ### Create Species, Locations, and Habitat Pattern Dictionaries

# %%
species_patterns = []
for row in species.iterrows():
    pattern = {'label': 'SPECIES', 'id': row[1]['taxonID']}
    pattern['pattern'] = [ { "LOWER": name.lower() } for name in row[1]['scientificName'].split(' ')]
    species_patterns.append(pattern)

# %%
location_patterns = []
for row in locations.iterrows():
    pattern = { "label": "LOCATIONS", 'id': str(row[1]['FEATURE_ID']) }
    pattern['pattern'] = [ { "LOWER": name.lower() } for name in row[1]['FEATURE_NAME'].split(" ") ]
    location_patterns.append(pattern)

# %%
habitat_patterns = []
for row in habitats.iterrows():
    pattern = {"label": "HABITAT"}
    pattern['pattern'] = [ {'LOWER': name.lower()} for name in row[1]['Habitat'].split(' ')]
    habitat_patterns.append(pattern)

# %% [markdown]
# Add `species`, `locations`, and `habitat` pattern dictionaries into the Entity Ruler

# %%
ruler.add_patterns(species_patterns)
ruler.add_patterns(location_patterns)
ruler.add_patterns(habitat_patterns)

# %% [markdown]
# Load helper functions from `lib/etl.py` module

# %%
import sys, os
sys.path.append("../src")
import lib.etl as etl

# %%
start = datetime.datetime.utcnow()
all_records = None
print(f"Start conversion at {start}")
for i, tei_path in enumerate(papers_tei.iterdir()):
    try:
        records = etl.process_xml(tei_path.read_bytes(), tei_path.name, nlp)
    except:
        print(f"Error with {tei_path.name}")
        continue
    if all_records is None:
        all_records = records
    else:
        all_records = pd.concat([all_records, records], ignore_index=True)
    if not i%10 and i > 0:
        print(".", end="")
    if not i%25 and i > 0:
        print(f"{i}", end="")
end = datetime.datetime.utcnow()
print(f"Finished at {end}, total time {(end-start).seconds / 60.} minutes")
# Out:
# Start conversion at 2021-03-15 20:56:10.125722
# ..25Finished at 2021-03-15 22:01:16.233183, total time 65.1 minutes

# %%
all_records.to_json("../data/records.json")

# %%
fhl = papers_tei/"fhl_2012_Townsend_27041.tei.xml"
fhl_df = etl.process_xml(fhl.read_bytes(), "fhl_2012_Townsend_27041.tei.xml", nlp)

# %%
fhl_df.head()
# Out:
#                           Paper ID                           Instance ID  \
# 0  fhl_2012_Townsend_27041.tei.xml  urn:lsid:marinespecies.org:taxname:6
# 1  fhl_2012_Townsend_27041.tei.xml  urn:lsid:marinespecies.org:taxname:6
# 2  fhl_2012_Townsend_27041.tei.xml  urn:lsid:marinespecies.org:taxname:6
#
#     Species                                               GBIF Time  \
# 0  bacteria  https://www.gbif.org/species/search?q=bacteria...
# 1  bacteria  https://www.gbif.org/species/search?q=bacteria...
# 2  bacteria  https://www.gbif.org/species/search?q=bacteria...
#
#         Place                      Habitats  div_enum
# 0       delta                  river,rivers         4
# 1       delta      marine,river,river mouth         5
# 2  Elwha,case  downstream,river,river mouth        21

# %%
fhl_paper1 = papers_tei/"fhl_2011_Bockmon_26635.tei.xml"

# %%
species_patterns[-1]
# Out:
# {'label': 'SPECIES',
#  'id': 'urn:lsid:marinespecies.org:taxname:1338746',
#  'pattern': [{'LOWER': 'relicanthus'}, {'LOWER': 'daphneae'}]}

# %%
nlp.component_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'senter',
#  'ner',
#  'attribute_ruler',
#  'lemmatizer',
#  'entity_ruler']

# %%
species = pd.read_json('../data/species.json')
locations = pd.read_json('../data/locations.json')
habitats = pd.read_json('../data/habitats.json')

# %%
species_dict = dict(zip(species.taxonID, species.scientificName))
location_dict = dict(zip(locations.FEATURE_ID, locations.FEATURE_NAME))

# %%
for key, val in species_dict.items():
    species_dict[key] = [val,]
for key, val in location_dict.items():
    location_dict[key] = [val,]

# %%
from spacy.language import Language

@Language.factory(name='species_entity')
def create_species_entity(nlp: Language, name: str):
    return Entity(name=name, keywords_dict=species_dict, label='SPECIES')

@Language.factory(name='location_entity')
def create_location_entity(nlp: Language, name: str):
    return Entity(name=name, keywords_dict=location_dict, label='LOCATION')

@Language.factory(name='habitat_entity')
def create_habitat_entity(nlp: Language, name: str):
    return Entity(name=name, keywords_list=list(habitats.Habitat), label='HABITAT')

# %%
nlp = spacy.load('en_core_web_md')
nlp.add_pipe('species_entity')
nlp.add_pipe('location_entity')
nlp.add_pipe('habitat_entity')
nlp.remove_pipe("ner")

# %%
start = datetime.datetime.utcnow()
all_records = None
print(f"Start conversion at {start}")
for i, tei_path in enumerate(papers_tei.iterdir()):
    try:
        records = etl.process_xml(tei_path.read_bytes(), tei_path.name, nlp)
    except:
        print(f"Error with {tei_path.name}")
        continue
    if all_records is None:
        all_records = records
    else:
        all_records = pd.concat([all_records, records], ignore_index=True)
    if not i%10 and i > 0:
        print(".", end="")
    if not i%25 and i > 0:
        print(f"{i}", end="")
end = datetime.datetime.utcnow()
print(f"Finished at {end}, total time {(end-start).seconds / 60.} minutes")
# Out:
# Start conversion at 2021-03-16 16:36:40.133033
# Error with fhl_2011_Brezicha_25959.tei.xml
# Error with fhl_2011_Bockmon_26635.tei.xml
# Error with fhl_2011_Broell_26677.tei.xml
# Error with fhl_2011_Phillips_26637.tei.xml
# Error with fhl_2011_Pierce_26647.tei.xml
# Error with fhl_2011_Paxton_25964.tei.xml
# Error with fhl_2011_Olmstead_26608.tei.xml
# Error with fhl_2011_Paxton_25962.tei.xml
# Error with fhl_2011_Lowe_26644.tei.xml
# Error with fhl_2011_LobatodeCarvalhoMartins_26645.tei.xml
# Error with fhl_2011_Little_26605.tei.xml
# Error with fhl_2011_Lipscomb_26604.tei.xml
# Error with fhl_2011_Lincoln_26623.tei.xml
# Error with fhl_2011_Lavelle_26625.tei.xml
# Error with fhl_2011_Lee_25961.tei.xml
# Error with fhl_2011_Pratt_26609.tei.xml
# Error with fhl_2011_Pietsch_26638.tei.xml
# Error with fhl_2011_Krauzser_26603.tei.xml
# Error with fhl_2011_Raymond_26989.tei.xml
# Error with fhl_2011_Barrera-Martinez_26627.tei.xml
# Error with fhl_2011_Hoang_26576.tei.xml
# Error with fhl_2011_Hoang_26634.tei.xml
# Error with fhl_2011_Andrykovich_26680.tei.xml
# Error with fhl_2011_Ho_26600.tei.xml
# Error with fhl_2011_Henderson_26998.tei.xml
# Error with fhl_2011_Stelter_26610.tei.xml
# Error with fhl_2011_Sato_26639.tei.xml
# Error with fhl_2011_Rickards_26617.tei.xml
# Error with fhl_2011_Hausch_26988.tei.xml
# Error with fhl_2011_Rico_26642.tei.xml
# Error with fhl_2011_Regan_26628.tei.xml
# Error with fhl_2011_Andrews_26679.tei.xml
# Error with fhl_2011_Sakamoto_26630.tei.xml
# Error with fhl_2011_Abe_26620.tei.xml
# Error with fhl_2011_Henderson_26805.tei.xml
# Error with fhl_2011_Bradshaw_26622.tei.xml
# Error with fhl_2011_Blackstone_26596.tei.xml
# Error with fhl_2011_Bonsell_26681.tei.xml
# Error with fhl_2011_Bourdillon_26568.tei.xml
# Error with fhl_2011_Clark_26624.tei.xml
# Error with fhl_2011_Contreras_26683.tei.xml
# Error with fhl_2011_Boeck_25968.tei.xml
# Error with fhl_2011_Chang_26632.tei.xml
# Error with fhl_2011_Challener_26614.tei.xml
# Error with fhl_2011_Guenther_26616.tei.xml
# Error with fhl_2011_Hausch_26806.tei.xml
# Error with fhl_2011_Gray_26631.tei.xml
# Error with fhl_2011_Gordon_25969.tei.xml
# Error with fhl_2012_Bansbach_27064.tei.xml
# Error with fhl_2012_Podell-Eberhardt_27003.tei.xml
# Error with fhl_2011_Suzumura_26611.tei.xml
# Error with fhl_2011_Taylor_26675.tei.xml
# Error with fhl_2011_Thomas_26598.tei.xml
# Error with fhl_2011_Dobkowski_26626.tei.xml
# Error with fhl_2011_Timm_26990.tei.xml
# Error with fhl_2011_Singer_25942.tei.xml
# Error with fhl_2011_Dawe_26633.tei.xml
# Error with fhl_2011_Eisenlord_26629.tei.xml
# Error with fhl_2011_Jethro_25970.tei.xml
# Error with fhl_2011_Cushman_26687.tei.xml
# Error with fhl_2011_Cox_26678.tei.xml
# Error with fhl_2012_Walkowicz_27024.tei.xml
# Error with fhl_2012_Burdi_27019.tei.xml
# Error with fhl_2012_Alika_27052.tei.xml
# Error with fhl_2012_Albrecht_27004.tei.xml
# Error with fhl_2012_Albrecht_27043.tei.xml
# Error with fhl_2011_Wu_26987.tei.xml
# Error with fhl_2011_Wright_26612.tei.xml
# Error with fhl_2011_Walls_25967.tei.xml
# Error with fhl_2011_Wilkins_26599.tei.xml
# Error with fhl_2012_Crawford_27015.tei.xml
# Error with fhl_2012_Green_27023.tei.xml
# Error with fhl_2012_Blattenbauer_26993.tei.xml
# Error with fhl_2012_Bruders_27305.tei.xml
# Error with fhl_2012_Brandkamp_27001.tei.xml
# Error with fhl_2012_Blair_27021.tei.xml
# Error with fhl_2012_Brackett_27008.tei.xml
# Error with fhl_2012_Bashevkin_27065.tei.xml
# Error with fhl_2012_Berg_27054.tei.xml
# Error with fhl_2013_Gunawan_27088.tei.xml
# Error with fhl_2013_Beaver_27199.tei.xml
# Error with fhl_2011_Gaessner_26699.tei.xml
# Error with fhl_2011_Enzor_26613.tei.xml
# Error with fhl_2011_Gilmore_26615.tei.xml
# Error with fhl_2011_Farrar_26643.tei.xml
# Error with fhl_2011_Kovac_26621.tei.xml
# Error with fhl_2011_Follis_26573.tei.xml
# Error with fhl_2011_Katagi_26641.tei.xml
# Error with fhl_2011_Kim_26574.tei.xml
# Error with fhl_2011_Kapsenberg_26636.tei.xml
# Error with fhl_2011_Kao_26602.tei.xml
# Error with fhl_2011_Johnson_26601.tei.xml
# Error with fhl_2011_Kane_25965.tei.xml
# Error with fhl_2011_Kane_25960.tei.xml
# Error with fhl_2011_Johnson_26572.tei.xml
# Error with fhl_2011_Navratil_26607.tei.xml
# Error with fhl_2011_Navratil_26594.tei.xml
# Error with fhl_2011_Newcomb_26618.tei.xml
# Error with fhl_2011_Miller_26646.tei.xml
# Error with fhl_2011_Meyer_26597.tei.xml
# Error with fhl_2011_Magley_26606.tei.xml
# Error with fhl_2011_Lucas_26648.tei.xml
# Error with fhl_2013_Bannister_27080.tei.xml
# Error with fhl_2013_Bashevkin_27097.tei.xml
# Error with fhl_2013_Apple_27194.tei.xml
# Error with fhl_2012_Weber_27078.tei.xml
# Error with fhl_2012_Wang_27051.tei.xml
# Error with fhl_2012_Williams_27014.tei.xml
# Error with fhl_2012_Williams_26995.tei.xml
# Error with fhl_2014_Kolmann_27267.tei.xml
# Error with fhl_2012_Walkowicz_27061.tei.xml
# Error with fhl_2013_Sabee_27193.tei.xml
# Error with fhl_2012_Wallace_27077.tei.xml
# Error with fhl_2014_Kendall-Bar_27206.tei.xml
# Error with fhl_2013_Lee_27101.tei.xml
# Error with fhl_2013_Le_27186.tei.xml
# Error with fhl_2013_LeDuc_27183.tei.xml
# Error with fhl_2013_Hasegawa_27084.tei.xml
# Error with fhl_2013_Hack_27100.tei.xml
# Error with fhl_2013_Highland_27090.tei.xml
# Error with fhl_2013_Levine-Weinberg_27102.tei.xml
# Error with fhl_2013_Gross_27188.tei.xml
# Error with fhl_2013_Haas_27182.tei.xml
# Error with fhl_2013_Gomez_27306.tei.xml
# Error with fhl_2013_Dubail_27083.tei.xml
# Error with fhl_2013_Gould_27089.tei.xml
# Error with fhl_2013_Glass_25573.tei.xml
# Error with fhl_2013_Gardner_27181.tei.xml
# Error with fhl_2013_Donohoe_27187.tei.xml
# Error with fhl_2013_Donatelli_27099.tei.xml
# Error with fhl_2013_Chavez_27098.tei.xml
# Error with fhl_2013_Brown_27185.tei.xml
# Error with fhl_2013_del Pozo_43820.tei.xml
# Error with fhl_2013_Brant_27081.tei.xml
# Error with fhl_2013_Brezak_27180.tei.xml
# Error with fhl_2013_Bliss_27093.tei.xml
# Error with fhl_2012_Crane_27068.tei.xml
# Error with fhl_2012_Contolini_27006.tei.xml
# Error with fhl_2012_Conery_27044.tei.xml
# Error with fhl_2012_Burton_27066.tei.xml
# Error with fhl_2012_Churches_27030.tei.xml
# Error with fhl_2012_Chow_27018.tei.xml
# Error with fhl_2012_Churches_27067.tei.xml
# Error with fhl_2013_Linney_27103.tei.xml
# Error with fhl_2012_Ge_27038.tei.xml
# Error with fhl_2012_Girardo_27032.tei.xml
# Error with fhl_2012_Goloff_27071.tei.xml
# Error with fhl_2012_Garcia_27059.tei.xml
# Error with fhl_2012_Garrison_27016.tei.xml
# Error with fhl_2012_Fodor_27031.tei.xml
# Error with fhl_2012_Fuller_27070.tei.xml
# Error with fhl_2012_Flanagan_27062.tei.xml
# Error with fhl_2012_Kimber_26997.tei.xml
# Error with fhl_2012_Knowlen_27000.tei.xml
# Error with fhl_2012_Johnson_26999.tei.xml
# Error with fhl_2012_Kareiva_27033.tei.xml
# Error with fhl_2012_Jacobsen-Watts_27045.tei.xml
# Error with fhl_2012_Huang_27028.tei.xml
# Error with fhl_2012_Huang_26996.tei.xml
# Error with fhl_2012_Heller_27005.tei.xml
# Error with fhl_2012_Hart_27002.tei.xml
# Error with fhl_2012_Haak_27072.tei.xml
# Error with fhl_2012_Hamel_27057.tei.xml
# Error with fhl_2012_Grewal_26994.tei.xml
# Error with fhl_2012_Oxborrow_27048.tei.xml
# Error with fhl_2012_Murphy_27025.tei.xml
# Error with fhl_2012_Nordstrom_27011.tei.xml
# Error with fhl_2012_Marks_27039.tei.xml
# Error with fhl_2012_Martin_27017.tei.xml
# Error with fhl_2012_McDowell_27056.tei.xml
# Error with fhl_2012_Malek_27063.tei.xml
# Error with fhl_2012_Mahone_27073.tei.xml
# Error with fhl_2012_Kulesza_27047.tei.xml
# Error with fhl_2012_Madden_27055.tei.xml
# Error with fhl_2012_Kreis_27046.tei.xml
# Error with fhl_2012_Driver_27069.tei.xml
# Error with fhl_2012_Eisenlord_27007.tei.xml
# Error with fhl_2012_Dunnell_27037.tei.xml
# Error with fhl_2012_Dougherty_27022.tei.xml
# Error with fhl_2012_Dunk_26992.tei.xml
# Error with fhl_2012_Dill_27020.tei.xml
# Error with fhl_2012_Deregibus_27053.tei.xml
# Error with fhl_2012_Darmawan_27027.tei.xml
# Error with fhl_2012_Davies_27036.tei.xml
# Error with fhl_2012_Walker_27304.tei.xml
# Error with fhl_2012_Villalobos_27076.tei.xml
# Error with fhl_2012_Vandepas_27029.tei.xml
# Error with fhl_2012_Voon_27050.tei.xml
# Error with fhl_2012_Tzubari_27058.tei.xml
# Error with fhl_2012_Twomey_27042.tei.xml
# Error with fhl_2012_Townsend_27041.tei.xml
# Error with fhl_2012_Tierney_27026.tei.xml
# Error with fhl_2012_Tierney_27060.tei.xml
# Error with fhl_2014_Bachhuber_34653.tei.xml
# Error with fhl_2012_Thomson_27013.tei.xml
# Error with fhl_2012_Teller_27010.tei.xml
# Error with fhl_2012_Swore_27035.tei.xml
# Error with fhl_2012_Stull_27049.tei.xml
# Error with fhl_2012_Sigley_27009.tei.xml
# Error with fhl_2012_Sission_27012.tei.xml
# Error with fhl_2014_Aarden_34579.tei.xml
# Error with fhl_2012_Sanford_27034.tei.xml
# Error with fhl_2012_Schreck_27040.tei.xml
# Error with fhl_2012_Rincón_27074.tei.xml
# Error with fhl_2012_Roberts_27075.tei.xml
# Error with fhl_2011_Wainwright_26695.tei.xml
# Error with fhl_2011_Vaughn_26640.tei.xml
# Error with fhl_2011_Vancil_26571.tei.xml
# Error with fhl_2011_Valenzuela_26619.tei.xml
# Error with fhl_2014_Hoins_27250.tei.xml
# Error with fhl_2011_Turnross_26991.tei.xml
# Error with fhl_2014_Geldof_27314.tei.xml
# Error with fhl_2011_Ulmke_26575.tei.xml
# Error with fhl_2014_Barrios_27259.tei.xml
# Error with fhl_2014_Dethier_34571.tei.xml
# Error with fhl_2014_Lou_34628.tei.xml
# Error with fhl_2013_Young_27177.tei.xml
# Error with fhl_2014_Aarden_27248.tei.xml
# Error with fhl_2013_Thompson_27096.tei.xml
# Error with fhl_2013_Yetsko_27175.tei.xml
# Error with fhl_2013_Yee_27174.tei.xml
# Error with fhl_2013_Wong_27173.tei.xml
# Error with fhl_2013_Sweeney_27178.tei.xml
# Error with fhl_2013_Stutz_27087.tei.xml
# Error with fhl_2013_Stephens_27197.tei.xml
# Error with fhl_2013_Standish_27091.tei.xml
# Error with fhl_2013_Simmons_27179.tei.xml
# Error with fhl_2013_Shutt_27196.tei.xml
# Error with fhl_2013_Simans_27176.tei.xml
# Error with fhl_2013_Schlatter_27094.tei.xml
# Error with fhl_2014_Chang_34623.tei.xml
# Error with fhl_2013_Putz_27192.tei.xml
# Error with fhl_2013_Rautu_27086.tei.xml
# Error with fhl_2013_Reynolds_25572.tei.xml
# Error with fhl_2013_Pineda_27172.tei.xml
# Error with fhl_2013_O’Neil_27191.tei.xml
# Error with fhl_2013_Nguyen_27171.tei.xml
# Error with fhl_2013_O’Connell_27190.tei.xml
# Error with fhl_2013_Pham_27095.tei.xml
# Error with fhl_2013_O’Neil_27184.tei.xml
# Error with fhl_2013_Newcomb_27195.tei.xml
# Error with fhl_2013_Nash_27189.tei.xml
# Error with fhl_2013_Nati_43821.tei.xml
# Error with fhl_2013_McCartha_27085.tei.xml
# Error with fhl_2014_Lebel_27264.tei.xml
# Error with fhl_2013_Lopez_27092.tei.xml
# Error with fhl_2014_LaFramboise_34576.tei.xml
# Error with fhl_2014_Lawrence_34562.tei.xml
# Error with fhl_2014_Lawrence_27245.tei.xml
# Error with fhl_2014_LaFramboise_27251.tei.xml
# Error with fhl_2014_Kolmann_34610.tei.xml
# Error with fhl_2014_Kruttschnitt_27602.tei.xml
# Error with fhl_2014_Anderson_27313.tei.xml
# Error with fhl_2014_McMahon_27211.tei.xml
# Error with fhl_2014_Allen_27270.tei.xml
# Error with fhl_2014_Acuña_27279.tei.xml
# Error with fhl_2014_Acuña_34631.tei.xml
# Error with fhl_2014_Beron_27201.tei.xml
# Error with fhl_2014_Page_27256.tei.xml
# Error with fhl_2014_Birkemeier_27286.tei.xml
# Error with fhl_2014_Jones_27274.tei.xml
# Error with fhl_2014_Harrison_27260.tei.xml
# Error with fhl_2014_Harrison_34580.tei.xml
# Error with fhl_2014_Gunawan_27242.tei.xml
# Error with fhl_2014_Hannah_34624.tei.xml
# Error with fhl_2014_Gunawan_34567.tei.xml
# Error with fhl_2014_Nigam_27254.tei.xml
# Error with fhl_2014_Furr_34629.tei.xml
# Error with fhl_2014_Furr_27283.tei.xml
# Error with fhl_2014_Finley_34535.tei.xml
# Error with fhl_2014_Ellis_34659.tei.xml
# Error with fhl_2014_Ellis_27234.tei.xml
# Error with fhl_2014_Finley_27204.tei.xml
# Error with fhl_2014_Fawcett_34578.tei.xml
# Error with fhl_2014_Fawcett_27249.tei.xml
# Error with fhl_2014_Donatelli_34609.tei.xml
# Error with fhl_2014_Elizabeth_34526.tei.xml
# Error with fhl_2014_Eakes_27317.tei.xml
# Error with fhl_2014_Ditsche_34532.tei.xml
# Error with fhl_2014_Donatelli_27263.tei.xml
# Error with fhl_2014_Chang_34613.tei.xml
# Error with fhl_2014_Chang_27271.tei.xml
# Error with fhl_2014_Cougan_27609.tei.xml
# Error with fhl_2014_Chang_27262.tei.xml
# Error with fhl_2014_Bynum_27605.tei.xml
# Error with fhl_2014_Bouilliart_34614.tei.xml
# Error with fhl_2014_Burke_27606.tei.xml
# Error with fhl_2014_Bouilliart_27261.tei.xml
# Error with fhl_2014_Birkemeier_34642.tei.xml
# Error with fhl_2014_Berentson_34661.tei.xml
# Error with fhl_2014_Berentson_27232.tei.xml
# Error with fhl_2014_Beets_34539.tei.xml
# Error with fhl_2014_Beets_27200.tei.xml
# Error with fhl_2014_Beaver_34540.tei.xml
# Error with fhl_2014_Barton_27607.tei.xml
# Error with fhl_2014_Barrios_34608.tei.xml
# Error with fhl_2014_Bigham_27312.tei.xml
# Error with fhl_2014_Thompson_27213.tei.xml
# Error with fhl_2014_Besso_34569.tei.xml
# Error with fhl_2014_Beron_34538.tei.xml
# Error with fhl_2014_Besso_27240.tei.xml
# Error with fhl_2014_Jones_34620.tei.xml
# Error with fhl_2014_Judge_27289.tei.xml
# Error with fhl_2014_Judge_34640.tei.xml
# Error with fhl_2014_Waits_34636.tei.xml
# Error with fhl_2015_Roberts_34665.tei.xml
# Error with fhl_2019_Waite_46669.tei.xml
# Error with fhl_2017_Gillespie_40369.tei.xml
# Error with fhl_2018_Armos_42595.tei.xml
# Error with fhl_2017_Lee_40370.tei.xml
# Error with fhl_2017_Finnegan_40368.tei.xml
# Error with fhl_2017_Coonfield_40367.tei.xml
# Error with fhl_2016_McLean_40365.tei.xml
# Error with fhl_2016_Ahmed_39250.tei.xml
# Error with fhl_2016_Omoto_40366.tei.xml
# Error with fhl_2016_Carr_37296.tei.xml
# Error with fhl_2015_Schneider_34664.tei.xml
# Error with fhl_2014_Wachter_34656.tei.xml
# Error with fhl_2014_Wachter_27238.tei.xml
# Error with fhl_2014_vanHemmen_34657.tei.xml
# Error with fhl_2014_vanHemmen_27237.tei.xml
# Error with fhl_2014_Truong_34525.tei.xml
# Error with fhl_2014_Tietbohl_27269.tei.xml
# Error with fhl_2014_Skavicus_34658.tei.xml
# Error with fhl_2014_Orzechowski_34649.tei.xml
# Error with fhl_2014_Corn_34612.tei.xml
# Error with fhl_2014_Corn_27266.tei.xml
# Error with fhl_2014_Orzechowski_27299.tei.xml
# Error with fhl_2014_Conrades_27202.tei.xml
# Error with fhl_2014_Conrades_27311.tei.xml
# Error with fhl_2014_Corcoran_34536.tei.xml
# Error with fhl_2014_Cisco_27241.tei.xml
# Error with fhl_2014_Cisco_34568.tei.xml
# Error with fhl_2014_Christianson_27233.tei.xml
# Error with fhl_2014_Christianson_34660.tei.xml
# Error with fhl_2014_Charifson_34622.tei.xml
# Error with fhl_2014_Charifson_27272.tei.xml
# Error with fhl_2014_Kendall-Bar_34533.tei.xml
# Error with fhl_2014_Koch_27275.tei.xml
# Error with fhl_2014_Koch_34619.tei.xml
# Error with fhl_2014_Gross_27287.tei.xml
# Error with fhl_2014_Gross_34641.tei.xml
# Error with fhl_2014_Ginsburg_34630.tei.xml
# Error with fhl_2014_Bachhuber_27296.tei.xml
# Error with fhl_2014_Graham_27608.tei.xml
# Error with fhl_2014_Ginsburg_27281.tei.xml
# Error with fhl_2014_Gidmark_34537.tei.xml
# Error with fhl_2014_Gerringer_34616.tei.xml
# Error with fhl_2014_Gerringer_27265.tei.xml
# Error with fhl_2014_Geoga_34621.tei.xml
# Error with fhl_2014_Ni_34572.tei.xml
# Error with fhl_2014_Geoga_27273.tei.xml
# Error with fhl_2014_Ng_34650.tei.xml
# Error with fhl_2014_Ni_27255.tei.xml
# Error with fhl_2014_Ng_34651.tei.xml
# Error with fhl_2014_Ng_27298.tei.xml
# Error with fhl_2014_Ng_27297.tei.xml
# Error with fhl_2014_Murphy_34574.tei.xml
# Error with fhl_2014_Murphy_27253.tei.xml
# Error with fhl_2014_Mumford_34573.tei.xml
# Error with fhl_2014_McQuaid_34639.tei.xml
# Error with fhl_2014_Milligan_27601.tei.xml
# Error with fhl_2014_Merz_27203.tei.xml
# Error with fhl_2014_McQuaid_27288.tei.xml
# Error with fhl_2014_McMahon_34528.tei.xml
# Error with fhl_2014_Johnson_27603.tei.xml
# Error with fhl_2014_Johnson_27205.tei.xml
# Error with fhl_2014_Holmberg_27244.tei.xml
# Error with fhl_2014_Holman_34564.tei.xml
# Error with fhl_2014_Hoins_34577.tei.xml
# Error with fhl_2014_Holman_27243.tei.xml
# Error with fhl_2019_Anteau_45637.tei.xml
# Error with fhl_2014_Hayes_27604.tei.xml
# Error with fhl_2014_White_27257.tei.xml
# Error with fhl_2019_Kawada_45644.tei.xml
# Error with fhl_2014_Ziegler_27293.tei.xml
# Error with fhl_2014_Tekola_34560.tei.xml
# Error with fhl_2014_Tassia_34637.tei.xml
# Error with fhl_2014_Tekola_27247.tei.xml
# Error with fhl_2014_Sullivan_34643.tei.xml
# Error with fhl_2014_Tassia_27291.tei.xml
# Error with fhl_2014_Sullivan_27302.tei.xml
# Error with fhl_2014_Solomon_34618.tei.xml
# Error with fhl_2014_Solomon_27277.tei.xml
# Error with fhl_2014_Sui_27212.tei.xml
# Error with fhl_2014_Sloan_34644.tei.xml
# Error with fhl_2014_Sui_34527.tei.xml
# Error with fhl_2014_Sloan_27301.tei.xml
# Error with fhl_2014_Lou_27284.tei.xml
# Error with fhl_2014_Levy_27252.tei.xml
# Error with fhl_2014_Lomax_34531.tei.xml
# Error with fhl_2014_Lomax_27208.tei.xml
# Error with fhl_2014_Linkem_27207.tei.xml
# Error with fhl_2014_Lebel_34615.tei.xml
# Error with fhl_2014_Levy_34575.tei.xml
# Error with fhl_2014_McKee_34611.tei.xml
# Error with fhl_2014_McKee_27268.tei.xml
# Error with fhl_2014_McGowan_34529.tei.xml
# Error with fhl_2014_McGowan_27210.tei.xml
# Error with fhl_2014_Mackaay_34561.tei.xml
# Error with fhl_2014_Mackaay_27246.tei.xml
# Error with fhl_2014_Maciel_34530.tei.xml
# Error with fhl_2014_Maciel_27209.tei.xml
# Error with fhl_2014_Lu_34652.tei.xml
# Error with fhl_2014_Lu_27303.tei.xml
# Error with fhl_2014_Lozano_34627.tei.xml
# Error with fhl_2014_Lozano_27282.tei.xml
# Error with fhl_2019_Thompson_45650.tei.xml
# Error with fhl_2019_Thompson_45651.tei.xml
# Error with fhl_2019_Titus_45652.tei.xml
# Error with fhl_2019_Rugila_46668.tei.xml
# Error with fhl_2019_Rugila_46667.tei.xml
# Error with fhl_2019_Riber_46674.tei.xml
# Error with fhl_2019_Wood_45653.tei.xml
# Error with fhl_2019_Pearson-Lund_45649.tei.xml
# Error with fhl_2019_Mateo_45647.tei.xml
# Error with fhl_2019_Mawson_45648.tei.xml
# Error with fhl_2019_Mari_46673.tei.xml
# Error with fhl_2019_Leventhal_46665.tei.xml
# Error with fhl_2019_Leatherman_45646.tei.xml
# Error with fhl_2019_Kimura_46672.tei.xml
# Error with fhl_2019_Kesting_45645.tei.xml
# Error with fhl_2019_González-Suárez_46664.tei.xml
# Error with fhl_2019_Hearther_45643.tei.xml
# Error with fhl_2019_Harshman_45642.tei.xml
# Error with fhl_2019_Gonzalez_45641.tei.xml
# Error with fhl_2019_Fagerström_46662.tei.xml
# Error with fhl_2019_Frank_46671.tei.xml
# Error with fhl_2019_Cullen_45640.tei.xml
# Error with fhl_2019_Chamorro_46661.tei.xml
# Error with fhl_2019_Fagerström_46663.tei.xml
# Error with fhl_2019_Chamorro_46294.tei.xml
# Error with fhl_2019_Cefalu_45639.tei.xml
# Error with fhl_2019_Becker_46670.tei.xml
# Error with fhl_2019_Benko_46666.tei.xml
# Error with fhl_2019_Arnold_45638.tei.xml
# Error with fhl_2014_Weber_34625.tei.xml
# Error with fhl_2014_Weber_27285.tei.xml
# Error with fhl_2014_Wang_34655.tei.xml
# Error with fhl_2014_Wang_27235.tei.xml
# Error with fhl_2014_Waits_27292.tei.xml
# Error with fhl_2014_Wood_34617.tei.xml
# Error with fhl_2014_Truong_27231.tei.xml
# Error with fhl_2014_Wyllie-Echeverria_34534.tei.xml
# Error with fhl_2014_Wood_27278.tei.xml
# Error with fhl_2014_Wilson_34654.tei.xml
# Error with fhl_2014_Wilson_27239.tei.xml
# Error with fhl_2014_White_34570.tei.xml
# Error with fhl_2014_ZayasdelRio_27335.tei.xml
# Error with fhl_2014_Skavicus_27236.tei.xml
# Error with fhl_2014_Schooler_27316.tei.xml
# Error with fhl_2014_Sampaga_34638.tei.xml
# Error with fhl_2014_Rummel_27276.tei.xml
# Error with fhl_2014_Sampaga_27290.tei.xml
# Error with fhl_2014_Rillera_34626.tei.xml
# Error with fhl_2014_Rillera_27280.tei.xml
# Error with fhl_2014_Richardson_27315.tei.xml
# Error with fhl_2014_Rebolledo_34646.tei.xml
# Error with fhl_2014_Rebolledo_27294.tei.xml
# Error with fhl_2014_Rebolledo_34645.tei.xml
# Error with fhl_2014_Parker_34648.tei.xml
# Error with fhl_2014_Parker_27295.tei.xml
# Error with fhl_2014_Rebolledo_27300.tei.xml
# Error with fhl_2015_Mayol_34666.tei.xml
# Error with fhl_2015_Oglesby_34801.tei.xml
# Error with fhl_2015_Laurence-Chasen_34667.tei.xml
# Error with fhl_2015_Kaczmarek_34707.tei.xml
# Error with fhl_2015_Jimenez_34793.tei.xml
# Error with fhl_2015_Fuerte-Stone_34794.tei.xml
# Error with fhl_2020_Meng_45591.tei.xml
# Error with fhl_2015_Dodgen_34802.tei.xml
# Error with fhl_2015_Dooley_34795.tei.xml
# Error with fhl_2015_Cotton_34796.tei.xml
# Error with fhl_2015_Corn_34797.tei.xml
# Error with fhl_2015_Bressman_34798.tei.xml
# Error with fhl_2015_Allen_34800.tei.xml
# Error with fhl_2014_Ziegler_34635.tei.xml
# Error with fhl_2015_BearMagallanes_34799.tei.xml
# Error with fhl_2014_Holmberg_34563.tei.xml
# Error with bml_Monteiro 2011_Summer Seq One.tei.xml
# Error with bml_Mateo 2011_Summer Seq One.tei.xml
# Error with bml_Noto 2011_Summer Seq One.tei.xml
# Error with bml_Reis 2011_Summer Seq Three.tei.xml
# Error with bml_Putney 2011_Summer Seq Three.tei.xml
# Error with bml_Ramirez 2011_Summer Seq One.tei.xml
# Error with bml_Slingsby 2011_Summer Seq Three.tei.xml
# Error with bml_Terry 2011 Summer Seq One.tei.xml
# Error with bml_Neifert 2011_Summer Seq Three.tei.xml
# Error with bml_Ng 2011_Summer Seq Three.tei.xml
# Error with bml_Maslanka 1_of_2 2011_SPRING.tei.xml
# Error with bml_Maddox 2011_SPRING.tei.xml
# Error with bml_Maslanka 2_of_2 2011_SPRING.tei.xml
# Error with bml_Lee 2011_Summer Seq Three.tei.xml
# Error with bml_Liang 2011_Summer Seq One.tei.xml
# Error with bml_Ferro 2011_Summer Seq Three.tei.xml
# Error with bml_Josias 2011_Summer Seq Three.tei.xml
# Error with bml_Elliott 2011_Summer Seq Three.tei.xml
# Error with bml_Gevertz 2011_Summer Seq One.tei.xml
# Error with bml_Knight 2011_Summer Seq One.tei.xml
# Error with bml_Gevertz 2011_Summer Seq Three.tei.xml
# Error with bml_Lawless 2011 Summer Seq One.tei.xml
# Error with bml_Shukla 2011_Summer Seq One.tei.xml
# Error with bml_Axton 2011_SPRING.tei.xml
# Error with bml_Ye 2011_SPRING.tei.xml
# Error with bml_Darrach 2011_Summer Seq One.tei.xml
# Error with bml_Wu 2011_Summer Seq One.tei.xml
# Error with bml_Avila-Hansen 2011 Summer Seq One.tei.xml
# Error with bml_Yeung 2011_Summer Seq One.tei.xml
# Error with bml_Carter 2011_Summer Seq Three.tei.xml
# Error with bml_Sauthoff 2011_Summer Seq Three.tei.xml
# Error with bml_Merala 2011_SPRING.tei.xml
# Error with bml_Shukla 2011_Summer Seq Three.tei.xml
# Error with bml_Chiang 2011_Summer Seq One.tei.xml
# Error with bml_Urbisci 2011_Summer Seq One.tei.xml
# Error with bml_Wilson 2011_SPRING.tei.xml
# Error with bml_Zeiger 2011_Summer Seq Three.tei.xml
# Error with hms_by815vx7135.tei.xml
# Error with bml_DeMars 2011 Summer Seq One.tei.xml
# Error with hms_bw265dn4321.tei.xml
# Error with hms_by836jp6882.tei.xml
# Error with hms_bv865bm7524.tei.xml
# Error with hms_bt693df6514.tei.xml
# Error with hms_bw715dy3162.tei.xml
# Error with hms_bw566wb6261.tei.xml
# Error with hms_bv466ms9813.tei.xml
# Error with hms_cb974cv3796.tei.xml
# Error with hms_bv745yv8760.tei.xml
# Error with hms_bt933jx4380.tei.xml
# Error with hms_bw012rf1456.tei.xml
# Error with hms_bt919wt2928.tei.xml
# Error with hms_bm995fm5755.tei.xml
# Error with hms_bm702qd5876.tei.xml
# Error with hms_bp501zs0258.tei.xml
# Error with hms_br379fc2115.tei.xml
# Error with hms_bp918hg1269.tei.xml
# Error with hms_bt252tc3244.tei.xml
# Error with hms_bn573hk3494.tei.xml
# Error with hms_bn277dh2861.tei.xml
# Error with hms_br897bp7238.tei.xml
# Error with hms_bq304yh4574.tei.xml
# Error with hms_bs155nx6248.tei.xml
# Error with hms_bt557qx6994.tei.xml
# Error with hms_bn022ny6724.tei.xml
# Error with hms_bn401mn6266.tei.xml
# Error with hms_bq417jb6307.tei.xml
# Error with hms_cs558kf6394.tei.xml
# Error with hms_cs158tm5329.tei.xml
# Error with hms_bm466nw8277.tei.xml
# Error with hms_bc922nf3500.tei.xml
# Error with hms_bj170wc5114.tei.xml
# Error with hms_bg648pk5690.tei.xml
# Error with hms_cd935wb7388.tei.xml
# Error with hms_cg226xb6985.tei.xml
# Error with hms_cf415gd8597.tei.xml
# Error with hms_bc118tw7158.tei.xml
# Error with hms_bc126qj9818.tei.xml
# Error with hms_cd938gz9516.tei.xml
# Error with hms_cc132kv2653.tei.xml
# Error with hms_bg894dp4809.tei.xml
# Error with hms_bb422yg7055.tei.xml
# Error with hms_bg870mr8040.tei.xml
# Error with hms_bh534nk5096.tei.xml
# Error with hms_hm548bn6620.tei.xml
# Error with hms_hp315qb1561.tei.xml
# Error with hms_ht346gy8993.tei.xml
# Error with hms_hn661cx7374.tei.xml
# Error with hms_hn307mb3303.tei.xml
# Error with hms_hv847kt6052.tei.xml
# Error with hms_hh477xb2523.tei.xml
# Error with hms_hg083pq3049.tei.xml
# Error with hms_hp100yt2360.tei.xml
# Error with hms_hd841fw2690.tei.xml
# Error with hms_hh459jj7308.tei.xml
# Error with hms_hr172yq9241.tei.xml
# Error with hms_hn290gc4297.tei.xml
# Error with hms_hs068fb4871.tei.xml
# Error with hms_fz579hz2608.tei.xml
# Error with hms_gd042bb2133.tei.xml
# Error with hms_fy174cn0666.tei.xml
# Error with hms_gc365gw1800.tei.xml
# Error with hms_hg072nm6762.tei.xml
# Error with hms_fy246vw6211.tei.xml
# Error with hms_fv212sx7044.tei.xml
# Error with hms_ft610nx5423.tei.xml
# Error with hms_fx492gj8509.tei.xml
# Error with hms_gc726hj1068.tei.xml
# Error with hms_fx682xq3476.tei.xml
# Error with hms_fw581kg7604.tei.xml
# Error with hms_fw763xr5150.tei.xml
# Error with hms_fv455jy7257.tei.xml
# Error with hms_dx537hg2250.tei.xml
# Error with hms_fz095rr8078.tei.xml
# Error with hms_dv849vy6751.tei.xml
# Error with hms_fz651gc1534.tei.xml
# Error with hms_dy063pf0945.tei.xml
# Error with hms_dq995jh3669.tei.xml
# Error with hms_ds477mv6523.tei.xml
# Error with hms_dq491jx7167.tei.xml
# Error with hms_dq639vg4816.tei.xml
# Error with hms_ds450bw7696.tei.xml
# Error with hms_dv385wb4436.tei.xml
# Error with hms_dr894zh9418.tei.xml
# Error with hms_ds974rm7007.tei.xml
# Error with hms_dx206mf4287.tei.xml
# Error with hms_dp781zq1319.tei.xml
# Error with hms_dx768dq4053.tei.xml
# Error with hms_fk792jy9343.tei.xml
# Error with hms_dv501gt7916.tei.xml
# Error with hms_dy642fy5124.tei.xml
# Error with hms_dz309tr0205.tei.xml
# Error with hms_dy691tk0356.tei.xml
# Error with hms_dz230sp9110.tei.xml
# Error with hms_ff116sx3936.tei.xml
# Error with hms_fh264zc5541.tei.xml
# Error with hms_fm608rg5696.tei.xml
# Error with hms_fj359nv5755.tei.xml
# Error with hms_dy697np5738.tei.xml
# Error with hms_fm956cm0364.tei.xml
# Error with hms_fd659xy4360.tei.xml
# Error with hms_fm267pm5475.tei.xml
# Error with hms_dy697pm1380.tei.xml
# Error with hms_db157mw0322.tei.xml
# Error with hms_fb672fg6716.tei.xml
# Error with hms_dd482ks2282.tei.xml
# Error with hms_cx810rw2690.tei.xml
# Error with hms_cy348kc3163.tei.xml
# Error with hms_cv346ct1192.tei.xml
# Error with hms_ct014sm6250.tei.xml
# Error with hms_cz809wv9170.tei.xml
# Error with hms_ct317ww1503.tei.xml
# Error with hms_cz995jf1615.tei.xml
# Error with hms_cx377bk6271.tei.xml
# Error with hms_ct322yh4644.tei.xml
# Error with hms_cv703ym9762.tei.xml
# Error with hms_cy434gz3432.tei.xml
# Error with hms_cz083mn0435.tei.xml
# Error with hms_cx996bj7104.tei.xml
# Error with hms_cs572bw0877.tei.xml
# Error with hms_cw528cb1986.tei.xml
# Error with hms_cj258ns3486.tei.xml
# Error with hms_ck831qg1826.tei.xml
# Error with hms_cg460kt7245.tei.xml
# Error with hms_ck775gm6824.tei.xml
# Error with hms_cm582pp5209.tei.xml
# Error with hms_ch792bx6307.tei.xml
# Error with hms_cp084fk4131.tei.xml
# Error with hms_ch106bz2018.tei.xml
# Error with hms_cj803sm7565.tei.xml
# Error with hms_ck629wy7344.tei.xml
# Error with hms_ck258mm9594.tei.xml
# Error with hms_cp949cw1173.tei.xml
# Error with hms_cq682rn2737.tei.xml
# Error with hms_cg716jc8702.tei.xml
# Error with hms_fr193by7414.tei.xml
# Error with hms_fs149vd6426.tei.xml
# Error with hms_fq577qf0530.tei.xml
# Error with hms_cp967xz4450.tei.xml
# Error with hms_fs726bz1794.tei.xml
# Error with hms_fq163fg5336.tei.xml
# Error with hms_fp865hj4022.tei.xml
# Error with hms_fq480td6419.tei.xml
# Error with hms_fq265ds8292.tei.xml
# Error with hms_fp335tq9198.tei.xml
# Error with hms_fn087wt7791.tei.xml
# Error with hms_fn798nk2018.tei.xml
# Error with hms_fp866tr8961.tei.xml
# Error with hms_fp662gc4663.tei.xml
# Error with hms_fr084jy8504.tei.xml
# Error with hms_jd241zr5849.tei.xml
# Error with hms_cr507tx4660.tei.xml
# Error with hms_cs130mm7602.tei.xml
# Error with hms_hx699cm5108.tei.xml
# Error with hms_jc204gf4523.tei.xml
# Error with hms_jc165nb2212.tei.xml
# Error with hms_hx187cf0379.tei.xml
# Error with hms_hy786qj8297.tei.xml
# Error with hms_jc598rf2102.tei.xml
# Error with hms_hw563hn9190.tei.xml
# Error with hms_hy197wn4891.tei.xml
# Error with hms_hz669ny4302.tei.xml
# Error with hms_jd254tq7230.tei.xml
# Error with hms_jb651sw8311.tei.xml
# Error with hms_jc150zt7895.tei.xml
# Error with hms_hw246sn8636.tei.xml
# Error with hms_jd585tv6099.tei.xml
# Error with hms_kj872hv4525.tei.xml
# Error with hms_kn291sy9852.tei.xml
# Error with hms_kp642sx7055.tei.xml
# Error with hms_kn750fz5175.tei.xml
# Error with hms_kr111tr5711.tei.xml
# Error with hms_kn589vc9260.tei.xml
# Error with hms_kr104zb7305.tei.xml
# Error with hms_kh091xd2231.tei.xml
# Error with hms_km939dh0573.tei.xml
# Error with hms_km536vc0108.tei.xml
# Error with hms_kj516jr2855.tei.xml
# Error with hms_kq645dr3054.tei.xml
# Error with hms_kp471py2564.tei.xml
# Error with hms_kp349ph4279.tei.xml
# Error with hms_kg704hs0496.tei.xml
# Error with hms_dh274rv1912.tei.xml
# Error with hms_dj537xs0798.tei.xml
# Error with hms_dp408wm2606.tei.xml
# Error with hms_dm903fg7460.tei.xml
# Error with hms_dn143kt6748.tei.xml
# Error with hms_dd517vt7809.tei.xml
# Error with hms_dd651qd6225.tei.xml
# Error with hms_dg065yp0282.tei.xml
# Error with hms_dm928gy2715.tei.xml
# Error with hms_dj224jp8743.tei.xml
# Error with hms_dh155bd7138.tei.xml
# Error with hms_dd642yc6528.tei.xml
# Error with hms_dd563mg5487.tei.xml
# Error with hms_dh491rk7392.tei.xml
# Error with hms_dj418cn6597.tei.xml
# Error with hms_gh443rd3001.tei.xml
# Error with hms_gp441gd9761.tei.xml
# Error with hms_gq801gw3740.tei.xml
# Error with hms_gg654sv7833.tei.xml
# Error with hms_gd149zw3968.tei.xml
# Error with hms_gm449pn2701.tei.xml
# Error with hms_gh334hw1023.tei.xml
# Error with hms_gr543wr7809.tei.xml
# Error with hms_gg717gf4801.tei.xml
# Error with hms_gk778my8810.tei.xml
# Error with hms_gq432dm3498.tei.xml
# Error with hms_gk908gf7509.tei.xml
# Error with hms_gn829cs9659.tei.xml
# Error with hms_gh227vp3933.tei.xml
# Error with hms_gj880nt8767.tei.xml
# Error with hms_jh262fy4143.tei.xml
# Error with hms_jg066nc8681.tei.xml
# Error with hms_jf167xj3667.tei.xml
# Error with hms_jj612gh5607.tei.xml
# Error with hms_jf998bd6235.tei.xml
# Error with hms_jh784kt2099.tei.xml
# Error with hms_jk857gq7944.tei.xml
# Error with hms_jk623zz7955.tei.xml
# Error with hms_jj634sg1375.tei.xml
# Error with hms_jg242zz9712.tei.xml
# Error with hms_jg442yz1213.tei.xml
# Error with hms_jk507bj1267.tei.xml
# Error with hms_jf183yx8228.tei.xml
# Error with hms_jg401tr3179.tei.xml
# Error with hms_mm126kx3565.tei.xml
# Error with hms_mw697bb8507.tei.xml
# Error with hms_jf704jm2106.tei.xml
# Error with hms_mv823hk1731.tei.xml
# Error with hms_mw341mm5407.tei.xml
# Error with hms_mk357tw0239.tei.xml
# Error with hms_mz464wt0187.tei.xml
# Error with hms_mn321mm7225.tei.xml
# Error with hms_ms165nc5925.tei.xml
# Error with hms_mx792sx4875.tei.xml
# Error with hms_my532hw1657.tei.xml
# Error with hms_my945pf2046.tei.xml
# Error with hms_mp542dc7305.tei.xml
# Error with hms_mk230xd4139.tei.xml
# Error with hms_mq814fz4962.tei.xml
# Error with hms_ms463wm9540.tei.xml
# Error with hms_rv381cz5530.tei.xml
# Error with hms_rk573jj6643.tei.xml
# Error with hms_rs239kd2024.tei.xml
# Error with hms_rq899jq8447.tei.xml
# Error with hms_rr729zy4959.tei.xml
# Error with hms_rp459vq0562.tei.xml
# Error with hms_rr151vm1107.tei.xml
# Error with hms_rn191kz1627.tei.xml
# Error with hms_rq402gk6364.tei.xml
# Error with hms_rs496kx0907.tei.xml
# Error with hms_rp277jm0600.tei.xml
# Error with hms_rv691xc8838.tei.xml
# Error with hms_rs682jc3909.tei.xml
# Error with hms_rt437gt3014.tei.xml
# Error with hms_rn624sw6560.tei.xml
# Error with hms_rc544kr7345.tei.xml
# Error with hms_rf366jh9862.tei.xml
# Error with hms_qz846bn3416.tei.xml
# Error with hms_rg834jz4569.tei.xml
# Error with hms_rb307dx4472.tei.xml
# Error with hms_rg367wp2677.tei.xml
# Error with hms_rc737ng4913.tei.xml
# Error with hms_rh817mp1016.tei.xml
# Error with hms_rg036qj0715.tei.xml
# Error with hms_rb153sk5690.tei.xml
# Error with hms_rc531cn9095.tei.xml
# Error with hms_rf451rm9914.tei.xml
# Error with hms_rf741fm9683.tei.xml
# Error with hms_rj241xn1601.tei.xml
# Error with hms_rv832tt5041.tei.xml
# Error with hms_rx657xg6562.tei.xml
# Error with hms_ry002zj8695.tei.xml
# Error with hms_rh743gf5542.tei.xml
# Error with hms_rz356zt5681.tei.xml
# Error with hms_rw030nc6762.tei.xml
# Error with hms_rw675nw0898.tei.xml
# Error with hms_rz999cp2998.tei.xml
# Error with hms_rw903fm9438.tei.xml
# Error with hms_sc371gd2809.tei.xml
# Error with hms_rw652nd5612.tei.xml
# Error with hms_sc046bm6102.tei.xml
# Error with hms_sc158qk0534.tei.xml
# Error with hms_rx718tt6977.tei.xml
# Error with hms_rw022ht8505.tei.xml
# Error with hms_gt984yp0187.tei.xml
# Error with hms_sd242ng7119.tei.xml
# Error with hms_gy531ft4379.tei.xml
# Error with hms_hd008gc7852.tei.xml
# Error with hms_gv579hx3954.tei.xml
# Error with hms_gt499jk0424.tei.xml
# Error with hms_gr619jn4381.tei.xml
# Error with hms_gv250yg8866.tei.xml
# Error with hms_gz293yq4738.tei.xml
# Error with hms_gy342bz7591.tei.xml
# Error with hms_gt049bq5068.tei.xml
# Error with hms_gv471qh7025.tei.xml
# Error with hms_gx021jv8425.tei.xml
# Error with hms_hc433kn8762.tei.xml
# Error with hms_qq810nv1357.tei.xml
# Error with hms_qx988cc7331.tei.xml
# Error with hms_qw813gk6928.tei.xml
# Error with hms_hb690yk2583.tei.xml
# Error with hms_qw711qb9619.tei.xml
# Error with hms_qr078tt0704.tei.xml
# Error with hms_gt282sm8931.tei.xml
# Error with hms_qy648vm2399.tei.xml
# Error with hms_qv064yb0078.tei.xml
# Error with hms_qs410rk7344.tei.xml
# Error with hms_qx224cq2708.tei.xml
# Error with hms_qw943nf1867.tei.xml
# Error with hms_qx899nh1508.tei.xml
# Error with hms_qs015gz3538.tei.xml
# Error with hms_qs770jp0291.tei.xml
# Error with hms_ng555hx8374.tei.xml
# Error with hms_qp741bv0734.tei.xml
# Error with hms_nh717jy0171.tei.xml
# Error with hms_nc027vz8731.tei.xml
# Error with hms_qw902bn3695.tei.xml
# Error with hms_nb350gx3796.tei.xml
# Error with hms_nf845vn5640.tei.xml
# Error with hms_nh248yq0504.tei.xml
# Error with hms_nc193dr3668.tei.xml
# Error with hms_nb100nt1777.tei.xml
# Error with hms_nc297kc1752.tei.xml
# Error with hms_nh762pm8735.tei.xml
# Error with hms_nh395bn8900.tei.xml
# Error with hms_nh409vn3792.tei.xml
# Error with hms_nd789dx8405.tei.xml
# Error with hms_kf764wh3371.tei.xml
# Error with hms_nh722qf4532.tei.xml
# Error with hms_jw427gt5299.tei.xml
# Error with hms_nc553ss6378.tei.xml
# Error with hms_jy310nk7292.tei.xml
# Error with hms_kd314mc7120.tei.xml
# Error with hms_jx202qr2870.tei.xml
# Error with hms_kf965rg6064.tei.xml
# Error with hms_jz332sx0273.tei.xml
# Error with hms_jy606bm0365.tei.xml
# Error with hms_kd078gy0288.tei.xml
# Error with hms_kd664nr7899.tei.xml
# Error with hms_kd740kw1105.tei.xml
# Error with hms_kd756jk2474.tei.xml
# Error with hms_jy659zv8134.tei.xml
# Error with hms_jx356kz5235.tei.xml
# Error with hms_jy065mz0038.tei.xml
# Error with hms_jw286vm6909.tei.xml
# Error with hms_jr495vj3445.tei.xml
# Error with hms_jn250rv9596.tei.xml
# Error with hms_jt086qc9403.tei.xml
# Error with hms_jw275hp6525.tei.xml
# Error with hms_jr869kc1313.tei.xml
# Error with hms_js820zm0945.tei.xml
# Error with hms_jn288nz9130.tei.xml
# Error with hms_jr937qn1797.tei.xml
# Error with hms_jv797pt3551.tei.xml
# Error with hms_jt129rc9460.tei.xml
# Error with hms_jn354br3670.tei.xml
# Error with hms_jn914mc7653.tei.xml
# Error with hms_jv053wr3186.tei.xml
# Error with hms_kx304hy3642.tei.xml
# Error with hms_jq882fj5572.tei.xml
# Error with hms_kw315rk3951.tei.xml
# Error with hms_kv604nc4015.tei.xml
# Error with hms_ks998zn1244.tei.xml
# Error with hms_kw682ny3339.tei.xml
# Error with hms_kt628vm0388.tei.xml
# Error with hms_ky063my8205.tei.xml
# Error with hms_ky486jz7788.tei.xml
# Error with hms_kv961jx2364.tei.xml
# Error with hms_mc581jy9772.tei.xml
# Error with hms_mc205gr4125.tei.xml
# Error with hms_kz082gy7932.tei.xml
# Error with hms_kx968qb7249.tei.xml
# Error with hms_kt525py3418.tei.xml
# Error with hms_nq222vq3582.tei.xml
# Error with hms_ns188fk6111.tei.xml
# Error with hms_ky616gk2958.tei.xml
# Error with hms_np974rr3186.tei.xml
# Error with hms_ns063ty7030.tei.xml
# Error with hms_nn395kx7210.tei.xml
# Error with hms_nj290fc6306.tei.xml
# Error with hms_nj806hk2317.tei.xml
# Error with hms_nj453dh1459.tei.xml
# Error with hms_nn511pc8323.tei.xml
# Error with hms_nj024df4209.tei.xml
# Error with hms_nj673gp4136.tei.xml
# Error with hms_ns428hx6548.tei.xml
# Error with hms_nq041fw0681.tei.xml
# Error with hms_nk428mv4278.tei.xml
# Error with hms_nm781vf8798.tei.xml
# Error with hms_pk018cn7913.tei.xml
# Error with hms_pf038zc9610.tei.xml
# Error with hms_pc942zt0521.tei.xml
# Error with hms_pn386nz0923.tei.xml
# Error with hms_pd794jg5260.tei.xml
# Error with hms_ph789wb4763.tei.xml
# Error with hms_pk656qr6331.tei.xml
# Error with hms_pk169md0101.tei.xml
# Error with hms_pd455zb7792.tei.xml
# Error with hms_pn523dm5752.tei.xml
# Error with hms_pm878wk8954.tei.xml
# Error with hms_pk872yj3133.tei.xml
# Error with hms_pg233vt2362.tei.xml
# Error with hms_pm789bv5122.tei.xml
# Error with hms_tb161vv9125.tei.xml
# Error with hms_pp392ph6148.tei.xml
# Error with hms_tb570hf9323.tei.xml
# Error with hms_sx632gk2708.tei.xml
# Error with hms_sw525mw9565.tei.xml
# Error with hms_sx767nf5765.tei.xml
# Error with hms_sv221ds2955.tei.xml
# Error with hms_sx251qg8995.tei.xml
# Error with hms_tb429nk3829.tei.xml
# Error with hms_tb251bq5125.tei.xml
# Error with hms_tb726md3338.tei.xml
# Error with hms_sy890gb2426.tei.xml
# Error with hms_tb801zn7429.tei.xml
# Error with hms_sy133xz3910.tei.xml
# Error with hms_sv288pv2581.tei.xml
# Error with hms_sz802jk5003.tei.xml
# Error with hms_mf099yt8446.tei.xml
# Error with hms_mj025vm9297.tei.xml
# Error with hms_mk064dg8527.tei.xml
# Error with hms_mk198rm2076.tei.xml
# Error with hms_mh941tj2907.tei.xml
# Error with hms_md596pr7679.tei.xml
# Error with hms_md140bw3647.tei.xml
# Error with hms_mg401pm1592.tei.xml
# Error with hms_mj526dg0556.tei.xml
# Error with hms_mf150rs6817.tei.xml
# Error with hms_md789qn9310.tei.xml
# Error with hms_mg761nc0661.tei.xml
# Error with hms_mf880gs4777.tei.xml
# Error with hms_mj294wy7750.tei.xml
# Error with hms_md075rk2206.tei.xml
# Error with hms_sk959hb7363.tei.xml
# Error with hms_sg555jd9473.tei.xml
# Error with hms_sf268cs7826.tei.xml
# Error with hms_sm457jf7850.tei.xml
# Error with hms_sm057bp1468.tei.xml
# Error with hms_sk676xd5688.tei.xml
# Error with hms_sh033st8655.tei.xml
# Error with hms_sg907jt2526.tei.xml
# Error with hms_sd270zk4456.tei.xml
# Error with hms_sm833zx5171.tei.xml
# Error with hms_sk334xp3948.tei.xml
# Error with hms_sf858vn4653.tei.xml
# Error with hms_sh113mk7232.tei.xml
# Error with hms_xx831dq7934.tei.xml
# Error with hms_sd300pt2223.tei.xml
# Error with hms_xx613gq3777.tei.xml
# Error with hms_xt976yk7645.tei.xml
# Error with hms_sj145rw4698.tei.xml
# Error with hms_xv884nf4649.tei.xml
# Error with hms_xs818vt1042.tei.xml
# Error with hms_xp887cr1055.tei.xml
# Error with hms_xz871ws0977.tei.xml
# Error with hms_xv472pr1817.tei.xml
# Error with hms_xx096sp7976.tei.xml
# Error with hms_xy829gy9956.tei.xml
# Error with hms_xr921ny4950.tei.xml
# Error with hms_xx534xk2981.tei.xml
# Error with hms_xp803pj2015.tei.xml
# Error with hms_vr090mx5432.tei.xml
# Error with hms_yc008md0158.tei.xml
# Error with hms_vp276vk6751.tei.xml
# Error with hms_yb900zh0028.tei.xml
# Error with hms_vr484jz4546.tei.xml
# Error with hms_vs109km7913.tei.xml
# Error with hms_vs407mk5010.tei.xml
# Error with hms_vs377bq7295.tei.xml
# Error with hms_vm982sz1370.tei.xml
# Error with hms_vp602hv4011.tei.xml
# Error with hms_vq951bm9252.tei.xml
# Error with hms_vr582hy6559.tei.xml
# Error with hms_vs430qf7721.tei.xml
# Error with hms_vr502bd5695.tei.xml
# Error with hms_vp112bk1362.tei.xml
# Error with hms_vr432qk8175.tei.xml
# Error with hms_vp899tw0139.tei.xml
# Error with hms_px135dq2568.tei.xml
# Error with hms_pv780dk7934.tei.xml
# Error with hms_pq670br0854.tei.xml
# Error with hms_pw486cr4201.tei.xml
# Error with hms_pw250vx5757.tei.xml
# Error with hms_pq050pm4386.tei.xml
# Error with hms_pr980qm4958.tei.xml
# Error with hms_pv572tw6344.tei.xml
# Error with hms_pt392fj6218.tei.xml
# Error with hms_pv645vd4333.tei.xml
# Error with hms_pv812ts3293.tei.xml
# Error with hms_ps440jv1289.tei.xml
# Error with hms_pv547yy0910.tei.xml
# Error with hms_pv918tm6564.tei.xml
# Error with hms_ps134nr9399.tei.xml
# Error with hms_zz504vb8339.tei.xml
# Error with hms_vy712nf1144.tei.xml
# Error with hms_vt408kc0688.tei.xml
# Error with hms_vz659pn5301.tei.xml
# Error with hms_vw444qv6816.tei.xml
# Error with hms_vt725xf9596.tei.xml
# Error with hms_vy298nv4603.tei.xml
# Error with hms_vt501dg7743.tei.xml
# Error with hms_vs829rg7450.tei.xml
# Error with hms_vv501wp2359.tei.xml
# Error with hms_vz980wk8856.tei.xml
# Error with hms_vy644vg8647.tei.xml
# Error with hms_vx198fs7727.tei.xml
# Error with hms_vv581xy0983.tei.xml
# Error with hms_vw383jj6666.tei.xml
# Error with hms_vw235hh4810.tei.xml
# Error with hms_qf079cr9136.tei.xml
# Error with hms_qc924pc4267.tei.xml
# Error with hms_py511jz8104.tei.xml
# Error with hms_qb110jh9554.tei.xml
# Error with hms_qb327rb2863.tei.xml
# Error with hms_qd735th3866.tei.xml
# Error with hms_py412rr4062.tei.xml
# Error with hms_qb430kw9092.tei.xml
# Error with hms_qf368wq1204.tei.xml
# Error with hms_qb003xy7666.tei.xml
# Error with hms_qd492mc8535.tei.xml
# Error with hms_px385ts2008.tei.xml
# Error with hms_qc399xj7463.tei.xml
# Error with hms_qd100kt4897.tei.xml
# Error with hms_py068kg3725.tei.xml
# Error with hms_nz642rc7867.tei.xml
# Error with hms_nz242yy3659.tei.xml
# Error with hms_ns719jb0246.tei.xml
# Error with hms_nw808qk7906.tei.xml
# Error with hms_ny271bx4969.tei.xml
# Error with hms_nw478jm4468.tei.xml
# Error with hms_ny294mz7853.tei.xml
# Error with hms_nv769sk2051.tei.xml
# Error with hms_ns950xn8467.tei.xml
# Error with hms_nw565rm7298.tei.xml
# Error with hms_ns758rq8453.tei.xml
# Error with hms_pb523xv0069.tei.xml
# Error with hms_nv426wv5592.tei.xml
# Error with hms_vm603kx9919.tei.xml
# Error with hms_nz877ps4069.tei.xml
# Error with hms_vd999tv5289.tei.xml
# Error with hms_nv107mv7338.tei.xml
# Error with hms_vb562pg6265.tei.xml
# Error with hms_vh900jx6207.tei.xml
# Error with hms_vm345yn0444.tei.xml
# Error with hms_vg487sc0489.tei.xml
# Error with hms_vm734vc9743.tei.xml
# Error with hms_vg638tm3494.tei.xml
# Error with hms_vb548rt0871.tei.xml
# Error with hms_vf662dy4113.tei.xml
# Error with hms_vd569fs6888.tei.xml
# Error with hms_vh496gy2768.tei.xml
# Error with hms_vm617hq7413.tei.xml
# Error with hms_vh988hp3457.tei.xml
# Error with hms_zy743nm1335.tei.xml
# Error with hms_zw424sh6750.tei.xml
# Error with hms_vc658bv4207.tei.xml
# Error with hms_zx920yy0133.tei.xml
# Error with hms_zt342rt9331.tei.xml
# Error with hms_zt612tr9901.tei.xml
# Error with hms_zt649tx6423.tei.xml
# Error with hms_zy209vz2829.tei.xml
# Error with hms_zx897dq3818.tei.xml
# Error with hms_zv793kt7104.tei.xml
# Error with hms_zt053kv6145.tei.xml
# Error with hms_zw387wm0746.tei.xml
# Error with hms_zs547gn6651.tei.xml
# Error with hms_zz472cp8582.tei.xml
# Error with hms_ty809dq3637.tei.xml
# Error with hms_zz467pc7918.tei.xml
# Error with hms_tv289wh6237.tei.xml
# Error with hms_zx520gf2751.tei.xml
# Error with hms_ty948by2094.tei.xml
# Error with hms_ty126gb3776.tei.xml
# Error with hms_tx918jd0279.tei.xml
# Error with hms_tp679mg0786.tei.xml
# Error with hms_ts362zt5058.tei.xml
# Error with hms_tx379qh2487.tei.xml
# Error with hms_tw466nt8857.tei.xml
# Error with hms_ty101nj1885.tei.xml
# Error with hms_ts624nm2714.tei.xml
# Error with hms_tv400sp0586.tei.xml
# Error with hms_tp222my6677.tei.xml
# Error with hms_vb217bz5448.tei.xml
# Error with hms_vb543zs9305.tei.xml
# Error with hms_zm833xm7783.tei.xml
# Error with hms_zm848vt7966.tei.xml
# Error with hms_zm262xm1657.tei.xml
# Error with hms_zm570dq3864.tei.xml
# Error with hms_zq716hn7310.tei.xml
# Error with hms_zq157sw3075.tei.xml
# Error with hms_zr656hx6102.tei.xml
# Error with hms_zn673kj0755.tei.xml
# Error with hms_zn608rj3688.tei.xml
# Error with hms_zq819qt2456.tei.xml
# Error with hms_zq245ch7184.tei.xml
# Error with hms_zr066mx9000.tei.xml
# Error with hms_zq777jy9239.tei.xml
# Error with hms_zn059pq7833.tei.xml
# Error with hms_zm389vw5414.tei.xml
# Error with hms_ym835zv5548.tei.xml
# Error with hms_yj387mc7765.tei.xml
# Error with hms_yk820yb7370.tei.xml
# Error with hms_yf406db3520.tei.xml
# Error with hms_yn581dq2038.tei.xml
# Error with hms_yc723wt1323.tei.xml
# Error with hms_ym492qz9870.tei.xml
# Error with hms_yc784fg0437.tei.xml
# Error with hms_yc349sj6032.tei.xml
# Error with hms_ym639xn5319.tei.xml
# Error with hms_yf344xh0056.tei.xml
# Error with hms_yh869zy1168.tei.xml
# Error with hms_yd595hw3173.tei.xml
# Error with hms_yc232fd6227.tei.xml
# Error with hms_tm948dg2801.tei.xml
# Error with hms_yf537vz9528.tei.xml
# Error with hms_tk399vk6086.tei.xml
# Error with hms_tc155kk6657.tei.xml
# Error with hms_tm928tw1945.tei.xml
# Error with hms_tp026fy0699.tei.xml
# Error with hms_tm409ws9863.tei.xml
# Error with hms_tm955qd9968.tei.xml
# Error with hms_tg590fw0097.tei.xml
# Error with hms_td038xn7686.tei.xml
# Error with hms_tj765wc4412.tei.xml
# Error with hms_tk237tn5183.tei.xml
# Error with hms_tj249tn1545.tei.xml
# Error with hms_tp140rz7595.tei.xml
# Error with hms_tn109mz7148.tei.xml
# Error with hms_td830hd7966.tei.xml
# Error with hms_wf165sm9862.tei.xml
# Error with hms_wd766yq1443.tei.xml
# Error with hms_wk582vj1460.tei.xml
# Error with hms_wm268rw3629.tei.xml
# Error with hms_wd046fb0824.tei.xml
# Error with hms_wg536rr9910.tei.xml
# Error with hms_wd017hj9493.tei.xml
# Error with hms_wg362cy7018.tei.xml
# Error with hms_wk830kx0867.tei.xml
# Error with hms_wd131gs1203.tei.xml
# Error with hms_wn187hc5152.tei.xml
# Error with hms_wj863xz3883.tei.xml
# Error with hms_wd531qx6560.tei.xml
# Error with hms_wg868vb5342.tei.xml
# Error with hms_qf458jv9134.tei.xml
# Error with hms_wj471vm6119.tei.xml
# Error with hms_qg767pc8244.tei.xml
# Error with hms_qp290ms3975.tei.xml
# Error with hms_qm940yy4890.tei.xml
# Error with hms_qf452fr7861.tei.xml
# Error with hms_qh567vb8521.tei.xml
# Error with hms_qk877nw5453.tei.xml
# Error with hms_qn190bk3831.tei.xml
# Error with hms_qj255kp0206.tei.xml
# Error with hms_qp670hy9478.tei.xml
# Error with hms_qg166tp0609.tei.xml
# Error with hms_qg908mv9057.tei.xml
# Error with hms_qp204hg2738.tei.xml
# Error with hms_qg798jp3314.tei.xml
# Error with hms_xn566yd4938.tei.xml
# Error with hms_qp387qh4760.tei.xml
# Error with hms_xd140rs0851.tei.xml
# Error with hms_xm868yf0239.tei.xml
# Error with hms_xh667fh2531.tei.xml
# Error with hms_xh960dw8645.tei.xml
# Error with hms_xj661cp2665.tei.xml
# Error with hms_xp173sv7043.tei.xml
# Error with hms_xk171dn4778.tei.xml
# Error with hms_xh991bx7947.tei.xml
# Error with hms_xj564ym9211.tei.xml
# Error with hms_xf417sb1995.tei.xml
# Error with hms_xd530mb2057.tei.xml
# Error with hms_xj777gb2429.tei.xml
# Error with hms_xp576zd1127.tei.xml
# Error with hms_xm929cb2902.tei.xml
# Error with hms_wv568pg0540.tei.xml
# Error with hms_wz914ym5348.tei.xml
# Error with hms_wy089vn2026.tei.xml
# Error with hms_wv907xy9005.tei.xml
# Error with hms_xc985ps2884.tei.xml
# Error with hms_wp009br6936.tei.xml
# Error with hms_xc035yb6768.tei.xml
# Error with hms_wv921gp7139.tei.xml
# Error with hms_ws510dg8605.tei.xml
# Error with hms_ww016rq1304.tei.xml
# Error with hms_wx514zn7036.tei.xml
# Error with hms_wz287xb5018.tei.xml
# Error with hms_wy020qg7245.tei.xml
# Error with hms_wp889zt7919.tei.xml
# Error with hms_wn855tz2421.tei.xml
# Error with hms_yw206cp4709.tei.xml
# Error with hms_yt097mj7388.tei.xml
# Error with hms_yw769kz8930.tei.xml
# Error with hms_ys997mk6425.tei.xml
# Error with hms_yt909bg9089.tei.xml
# Error with hms_yt773vj2075.tei.xml
# Error with hms_yx108ph1438.tei.xml
# Error with hms_yr619fq5792.tei.xml
# Error with hms_yp314yw7618.tei.xml
# Error with hms_yr110nc0938.tei.xml
# Error with hms_yp845kr9304.tei.xml
# Error with hms_yn940nd6826.tei.xml
# Error with hms_yn828sk0354.tei.xml
# Error with hms_yr682kb1720.tei.xml
# Error with hms_sr295mp9249.tei.xml
# Error with hms_sn322nz4834.tei.xml
# Error with hms_ss560xf4777.tei.xml
# Error with hms_yw713rr2289.tei.xml
# Error with hms_sp137cb8729.tei.xml
# Error with hms_sp748fh0527.tei.xml
# Error with hms_sm915yx0709.tei.xml
# Error with hms_sp795pd7881.tei.xml
# Error with hms_sr234qh4295.tei.xml
# Error with hms_sp106xb3178.tei.xml
# Error with hms_sp871qz0159.tei.xml
# Error with hms_sr097dz1109.tei.xml
# Error with hms_st459hc0805.tei.xml
# Error with hms_sr937tk7048.tei.xml
# Error with hms_sv092zw7960.tei.xml
# Error with hms_zd991zr2750.tei.xml
# Error with hms_sp037fc1250.tei.xml
# Error with hms_zj654fg3583.tei.xml
# Error with hms_zb664mj4435.tei.xml
# Error with hms_zk162qr1610.tei.xml
# Error with hms_yy912bw8553.tei.xml
# Error with hms_yx237cc7402.tei.xml
# Error with hms_zh533tf3165.tei.xml
# Error with hms_zc634wm4735.tei.xml
# Error with hms_zj037qn1464.tei.xml
# Error with hms_yz643pc0742.tei.xml
# Error with hms_yz103jq2336.tei.xml
# Error with hms_zh604ny4735.tei.xml
# Error with hms_zc746my4987.tei.xml
# Error with hms_zk666qn4691.tei.xml
# Error with hms_zd610ry2635.tei.xml
# Error with hms_jk455dd2140.tei.xml
# Error with hms_pz596wd3318.tei.xml
# Error with hms_wv511gn1089.tei.xml
# Error with hms_wt810mw5450.tei.xml
# Error with hms_bv172tc9618.tei.xml
# Error with hms_pz380bx9306.tei.xml
# Error with fhl_1982_Olson_43828.tei.xml
# Error with carl_1978_KanegawaJayT.tei.xml
# Error with carl_1978_LewisLark.tei.xml
# Error with carl_1978_SchlenkCornelia.tei.xml
# Error with carl_1978_PetersonBarbara.tei.xml
# Error with carl_1978_ReaMarjory.tei.xml
# Error with carl_1983_DownieAlanA.tei.xml
# Error with carl_1978_Levitt_and_Wood.tei.xml
# Error with carl_1978_OlsonEric.tei.xml
# Error with carl_1978_JungPatti.tei.xml
# Error with carl_1983_BurgesonSteve.tei.xml
# Error with carl_1983_Choy_and_Williams.tei.xml
# Error with carl_1983_BunikMayaE.tei.xml
# Error with carl_1978_TylerJeffreyD.tei.xml
# Error with carl_1978_JohnsonSusan.tei.xml
# Error with carl_1978_StorkJohnJ.tei.xml
# Error with carl_1983_Blosberg_and_Neidhart.tei.xml
# Error with carl_1983_RothwellJennifer.tei.xml
# Error with carl_1978_RileySuzanne.tei.xml
# Error with carl_1983_OlanderAndrea.tei.xml
# Error with carl_1978_SpornThomasA.tei.xml
# Error with carl_1983_NiemanRobertS.tei.xml
# Error with carl_1983_McCuskeyCharles.tei.xml
# Error with carl_1983_KaufmanDavid.tei.xml
# Error with carl_1983_ConeryJohn.tei.xml
# Error with carl_1983_Golde_and_Wright.tei.xml
# Error with carl_1983_Heck_and_Rodkin.tei.xml
# Error with carl_1983_VincentAlexandra.tei.xml
# Error with carl_1986_Adams_and_Laurenson.tei.xml
# Error with carl_1986_Bailey_and_Onello.tei.xml
# Error with carl_1983_SmithRon.tei.xml
# Error with carl_1983_ShaughnessyAnn.tei.xml
# Error with carl_1983_SpringerScottR.tei.xml
# Error with carl_1978_BuffingtonSteve.tei.xml
# Error with carl_1983_SewellAmyT.tei.xml
# Error with carl_1986_ShimetaJeffreyS.tei.xml
# Error with carl_1986_TurnerFernandaB.tei.xml
# Error with carl_1986_RiedelPatrickJ.tei.xml
# Error with carl_1986_EdingerDavidT.tei.xml
# Error with carl_1986_LemoinePhilippeH.tei.xml
# Error with carl_1978_FleisherMark.tei.xml
# Error with carl_1978_FosterTedF.tei.xml
# Error with carl_1986_Hankins_and_Swift.tei.xml
# Error with carl_1978_DoullLisa.tei.xml
# Error with carl_1978_JohnsonDave.tei.xml
# Error with ucla_1975_YoungKeith.tei.xml
# Error with carl_1978_EifrigDavidE.tei.xml
# Error with ucla_1975_StarczakVictoria.tei.xml
# Error with ucla_1975_RoquemoreFrank.tei.xml
# Error with ucla_1975_WatsonCandiceA.tei.xml
# Error with ucla_1975_PetersonScott.tei.xml
# Error with ucla_1975_ShulmanMyra.tei.xml
# Error with ucla_1975_NelsonBobette.tei.xml
# Error with ucla_1978_ContrerasDavid_Phaustor.tei.xml
# Error with ucla_1989_GombinerMichael.tei.xml
# Error with ucla_1975_YuenGeoffrey.tei.xml
# Error with ucla_1975_ZimmermanRichard.tei.xml
# Error with ucla_1987_HuangMay.tei.xml
# Error with ucla_1978_ContrerasDavid_Spurpuratus.tei.xml
# Error with ucla_1975_WinklerDelaine.tei.xml
# Error with ucla_1978_FoonWarrenD_Mcalifornianus.tei.xml
# Error with ucla_1978_FirpoJanine_DensityDiversity.tei.xml
# Error with ucla_1978_ContrerasDavid_Mpyrifera.tei.xml
# Error with ucla_1978_FoonWarrenD_Asertulifera.tei.xml
# Error with ucla_1978_FoonWarrenD_Hydractinia.tei.xml
# Error with ucla_1978_FirpoJanine_Dornata.tei.xml
# Error with ucla_1978_FirpoJanine_Cpellucida.tei.xml
# Error with usc_1976_Su_INDEX.tei.xml
# Error with ucla_1978_IstrinJosef_Cnicholsii.tei.xml
# Error with ucla_1978_RexonMichaelC_PredatorAvoidance.tei.xml
# Error with ucla_1978_IstrinJosef_Mpyrifera.tei.xml
# Error with ucla_1978_GibsonMellie_HermitCrab.tei.xml
# Error with ucla_1978_RexonMichaelC_Octopus.tei.xml
# Error with ucla_1978_GibsonMellie_Ophiuroids.tei.xml
# Error with ucla_1978_GibsonMellie_Gobies.tei.xml
# Error with ucla_1978_IstrinJosef_Encrusting.tei.xml
# Error with ucla_1978_SkollerDebbie_Sspinosus.tei.xml
# Error with ucla_1978_SkollerDebbie_Escape.tei.xml
# Error with ucla_1981_BaschLawrenceV.tei.xml
# Error with ucla_1978_SkollerDebbie_EnvComplexity.tei.xml
# Error with ucla_1978_RexonMichaelC_Tegula.tei.xml
# Error with ucla_1981_BoydTerrence.tei.xml
# Error with ucla_1981_HughesBrian.tei.xml
# Error with ucla_1981_JonesJames.tei.xml
# Error with ucla_1981_GallardoMark.tei.xml
# Error with ucla_1981_DemetriouStevenJ.tei.xml
# Error with ucla_1981_FineDavid.tei.xml
# Error with ucla_1981_DaparRhysV.tei.xml
# Error with usc_1994_Sp_Long.tei.xml
# Error with ucla_1981_WuestehubeLindaJ.tei.xml
# Error with ucla_1983_CoghlanVincent.tei.xml
# Error with ucla_1981_SchultzeElaine.tei.xml
# Error with ucla_1983_BoyajianLisaS.tei.xml
# Error with ucla_1981_VogelSteve.tei.xml
# Error with ucla_1981_SorourSima.tei.xml
# Error with ucla_1987_AlterAndrew.tei.xml
# Error with ucla_1981_McAlaryFlorence.tei.xml
# Error with ucla_1983_SextonMark.tei.xml
# Error with ucla_1983_ShayaniVafa.tei.xml
# Error with ucla_1983_StreifingerConnie.tei.xml
# Error with ucla_1983_GladstoneSusan.tei.xml
# Error with ucla_1983_NiessenKenneth.tei.xml
# Error with ucla_1983_McClainRichard.tei.xml
# Error with ucla_1987_HillLauraH.tei.xml
# Error with ucla_1983_LeonardElaine.tei.xml
# Error with ucla_1987_HoPhilipT.tei.xml
# Error with ucla_1983_HenryBrian.tei.xml
# Error with ucla_1987_DoinoJudith.tei.xml
# Error with ucla_1987_FischerRachel.tei.xml
# Error with ucla_1987_DobakJohn.tei.xml
# Error with ucla_1983_StummerCindy.tei.xml
# Error with ucla_1983_SturmNancy.tei.xml
# Error with ucla_1987_Ben-TalOfer.tei.xml
# Error with ucla_1987_BlankAryeR.tei.xml
# Error with ucla_1987_SchabesMauricio.tei.xml
# Error with ucla_1987_ShapiroDanielF.tei.xml
# Error with ucla_1987_OrmsbyBernard.tei.xml
# Error with ucla_1987_KhubesrianMarina.tei.xml
# Error with ucla_1987_ReichenbergerPatrick.tei.xml
# Error with ucla_1988_GoldbergJoel.tei.xml
# Error with ucla_1988_GaidaIngo.tei.xml
# Error with ucla_1987_WeissmanDavida.tei.xml
# Error with ucla_1988_BrownLynn.tei.xml
# Error with ucla_1988_OstiGreg.tei.xml
# Error with ucla_1988_ReisewitzShauna.tei.xml
# Error with ucla_1988_MurrayMike.tei.xml
# Error with ucla_1988_LeGassickMatthew.tei.xml
# Error with ucla_1988_NeriGes-Mari.tei.xml
# Error with ucla_1988_MillarRenee.tei.xml
# Error with ucla_1988_MadsenSteve.tei.xml
# Error with ucla_1988_HansenKimberly.tei.xml
# Error with ucla_1989_BoyleKarleen.tei.xml
# Error with ucla_1989_BaghdasarianGaren.tei.xml
# Error with ucla_1988_WylieTodd.tei.xml
# Error with ucla_1989_ArnoldKristian.tei.xml
# Error with ucla_1989_AlessiNicole.tei.xml
# Error with ucla_1988_TorresElizabeth.tei.xml
# Error with ucla_1988_RuputEmily.tei.xml
# Error with ucla_1988_SanchezShelley.tei.xml
# Error with ucla_1988_SchemmelGreg.tei.xml
# Error with ucla_1989_HorvathPatricia.tei.xml
# Error with ucla_1989_ClelandDavid.tei.xml
# Error with ucla_1989_EvansKatherene.tei.xml
# Error with ucla_1989_EllisErik.tei.xml
# Error with ucla_1989_BennettMartinA.tei.xml
# Error with ucla_1989_DaleyShawn.tei.xml
# Error with ucla_1989_GuySusan.tei.xml
# Error with ucla_1989_SundolMark.tei.xml
# Error with ucla_1989_RynearsonRobert.tei.xml
# Error with ucla_1989_LolyCarla.tei.xml
# Error with ucla_1989_LonhartSteve.tei.xml
# Error with ucla_1989_MarKelvin.tei.xml
# Error with ucla_1989_KaisSam.tei.xml
# Error with ucla_1989_LarsonCoreenE.tei.xml
# Error with ucla_1989_KatsumataKristin.tei.xml
# Error with usc_1998_Sp_Pham.tei.xml
# Error with ucla_1975_NakanoDuane.tei.xml
# Error with ucla_1975_MotolaEd.tei.xml
# Error with usc_1998_Sp_Walker.tei.xml
# Error with ucla_1975_EgstromGail.tei.xml
# Error with ucla_1975_BuckleyGary.tei.xml
# Error with ucla_1989_MizuguchiNana.tei.xml
# Error with ucla_1975_ChapmanJohn_Asculpta.tei.xml
# Error with ucla_1975_BrownGarry.tei.xml
# Error with ucla_1975_ChapmanJohn_tempSal.tei.xml
# Error with ucla_1975_BaxterDiane.tei.xml
# Error with usc_2000_Corber.tei.xml
# Error with usc_2000_Cabalo.tei.xml
# Error with usc_2000_Burnfeind.tei.xml
# Error with usc_2000_Hornick.tei.xml
# Error with usc_2000_Carr.tei.xml
# Error with usc_1998_Sp_Rumrill_and_Cohen.tei.xml
# Error with usc_2000_Allen.tei.xml
# Error with usc_2000_Sommelet.tei.xml
# Error with usc_2000_Thoroughman.tei.xml
# Error with usc_2000_Seeman.tei.xml
# Error with usc_2000_Ahmed.tei.xml
# Error with usc_2000_Solis.tei.xml
# Error with usc_2000_Kneeling.tei.xml
# Error with usc_2000_Sin.tei.xml
# Error with usc_2000_Le.tei.xml
# Error with usc_2000_Kim.tei.xml
# Error with usc_2000_Jackson.tei.xml
# Error with usc_1971_Henon.tei.xml
# Error with usc_1971_Coyer.tei.xml
# Error with usc_1970_Woollacoot.tei.xml
# Error with usc_1972_Christopherson.tei.xml
# Error with usc_1971_Citek.tei.xml
# Error with usc_1971_Roseland.tei.xml
# Error with usc_1970_Maruyama.tei.xml
# Error with usc_1970_Morel.tei.xml
# Error with usc_2000_Vanhoof.tei.xml
# Error with usc_2000_Zenarosa.tei.xml
# Error with usc_1973_Sp_Neighbors.tei.xml
# Error with usc_1973_Sp_Jolie.tei.xml
# Error with usc_1973_Sp_Johnson.tei.xml
# Error with usc_1973_Sp_Brewer.tei.xml
# Error with usc_1973_Sp_Hadley.tei.xml
# Error with usc_1973_Sp_Engle.tei.xml
# Error with usc_1973_Sp_Beckwitt.tei.xml
# Error with usc_1972_Roseland.tei.xml
# Error with usc_1973_Sp_Beeler.tei.xml
# Error with usc_1974_SpFa_Jelley.tei.xml
# Error with usc_1974_SpFa_Akers_etal.tei.xml
# Error with usc_1972_Kretz.tei.xml
# Error with usc_1974_SpFa_Gardner_and_Zimmerman.tei.xml
# Error with usc_1973_Sp_Wojcik.tei.xml
# Error with usc_1973_Sp_Swank.tei.xml
# Error with usc_1974_SpFa_Akers_and_King.tei.xml
# Error with usc_1974_SpFa_Hart.tei.xml
# Error with usc_1973_Sp_Rischen.tei.xml
# Error with usc_1976_Su_Zahary.tei.xml
# Error with usc_1977_Sp_Evidon.tei.xml
# Error with usc_1977_Sp_Cho.tei.xml
# Error with usc_1976_Su_Green.tei.xml
# Error with usc_1977_Sp_Hartman.tei.xml
# Error with usc_1976_Su_Fuentes.tei.xml
# Error with usc_1976_Su_Baez.tei.xml
# Error with usc_1976_Su_Baez_2.tei.xml
# Error with usc_1976_Su_Boudreau.tei.xml
# Error with usc_1977_Su_Bensen.tei.xml
# Error with usc_1977_Su_Behrents.tei.xml
# Error with usc_1974_SpFa_Lissner.tei.xml
# Error with usc_1977_Sp_Thun.tei.xml
# Error with usc_1974_SpFa_Kidd.tei.xml
# Error with usc_1977_Sp_Starrett_Currents.tei.xml
# Error with usc_1977_Sp_Pahlavan.tei.xml
# Error with usc_1977_Sp_Starrett_Asculpta.tei.xml
# Error with usc_1977_Sp_Muleady.tei.xml
# Error with usc_1977_Sp_Moore.tei.xml
# Error with usc_1977_Sp_Regnante.tei.xml
# Error with usc_1977_Su_Rand.tei.xml
# Error with usc_1977_Su_Richardson.tei.xml
# Error with usc_1977_Sp_Hourigan.tei.xml
# Error with usc_1977_Su_Meisler.tei.xml
# Error with usc_1977_Su_Ishimatsu.tei.xml
# Error with usc_1977_Su_Krempin.tei.xml
# Error with usc_1977_Su_Hickey.tei.xml
# Error with usc_1977_Su_Hageman.tei.xml
# Error with usc_1977_Su_Geiger.tei.xml
# Error with usc_1977_Su_Dmohowski.tei.xml
# Error with usc_1978_Coyne_etal.tei.xml
# Error with usc_1978_Palmer.tei.xml
# Error with usc_1978_Levitt_and_Wood.tei.xml
# Error with usc_1978_Gibson.tei.xml
# Error with usc_1978_Foon.tei.xml
# Error with usc_1978_Katnik_etal.tei.xml
# Error with usc_1978_Butsumyo_etal.tei.xml
# Error with usc_1977_Su_Welden.tei.xml
# Error with usc_1977_Su_Stepien.tei.xml
# Error with usc_1979_Su_Mitchell.tei.xml
# Error with usc_1979_Su_Guckelberg.tei.xml
# Error with usc_1979_Su_Payne.tei.xml
# Error with usc_1979_Su_Resca.tei.xml
# Error with usc_1979_Su_Colton.tei.xml
# Error with usc_1979_Su_Covin.tei.xml
# Error with usc_1979_Su_Bergen.tei.xml
# Error with usc_1979_Su_Gerard.tei.xml
# Error with usc_1979_Sp_Sullivan.tei.xml
# Error with usc_1982_Su_Pittenger.tei.xml
# Error with usc_1982_Su_Gerard_etal.tei.xml
# Error with usc_1982_Su_Jara.tei.xml
# Error with usc_1982_Su_Escobar_Briones.tei.xml
# Error with usc_1982_Su_Farley.tei.xml
# Error with usc_1979_Su_Ryall.tei.xml
# Error with usc_1979_Su_Wheatley.tei.xml
# Error with usc_1979_Su_Pond.tei.xml
# Error with usc_1979_Sp_Smithwich.tei.xml
# Error with usc_1990_V1_Mensa.tei.xml
# Error with usc_1990_V1_Edge.tei.xml
# Error with usc_1990_V1_Kremer.tei.xml
# Error with usc_1990_V1_Chu.tei.xml
# Error with usc_1990_V1_Kilmer.tei.xml
# Error with usc_1990_V1_Hoffman.tei.xml
# Error with usc_1990_V1_Chavez_Villalba.tei.xml
# Error with usc_1983_Su_Aguilar.tei.xml
# Error with usc_1982_Su_Krause.tei.xml
# Error with usc_1982_Su_Yourke.tei.xml
# Error with usc_1990_V2_Chu.tei.xml
# Error with usc_1990_V1_Vilavicencio.tei.xml
# Error with usc_1990_V1_Sekiguchi.tei.xml
# Error with usc_1990_V2_Axayacatl.tei.xml
# Error with usc_1990_V1_Yoshimi.tei.xml
# Error with usc_1990_V1_Sohn.tei.xml
# Error with usc_1990_V1_Modean.tei.xml
# Error with usc_1990_V1_Reischauer.tei.xml
# Error with usc_1990_V2_Silva.tei.xml
# Error with usc_1990_V1_Olivares.tei.xml
# Error with usc_1990_V2_Sekiguchi.tei.xml
# Error with usc_1990_V2_Mensa.tei.xml
# Error with usc_1990_V2_Reischauer.tei.xml
# Error with usc_1990_V2_Deeb.tei.xml
# Error with usc_1990_V2_Kilmer.tei.xml
# Error with usc_1990_V2_Modean.tei.xml
# Error with usc_1990_V2_Edge.tei.xml
# Error with usc_1991_Sp_Mazzella.tei.xml
# Error with usc_1990_V2_Chavez.tei.xml
# Error with usc_1991_Sp_McCormick.tei.xml
# Error with usc_1991_Sp_Leonard.tei.xml
# Error with usc_1991_Sp_Mahoney.tei.xml
# Error with usc_1991_Sp_Martinez.tei.xml
# Error with usc_1991_Sp_Koko.tei.xml
# Error with usc_1991_Sp_Chawla.tei.xml
# Error with usc_1991_Sp_Hentschke.tei.xml
# Error with usc_1991_Sp_Bash.tei.xml
# Error with usc_1990_V2_Sohn.tei.xml
# Error with usc_1990_V2_Yoshimi.tei.xml
# Error with usc_1992_Sp_Gala.tei.xml
# Error with usc_1992_Sp_Fleming.tei.xml
# Error with usc_1991_Sp_Western.tei.xml
# Error with usc_1992_Sp_Brain.tei.xml
# Error with usc_1991_Sp_White.tei.xml
# Error with usc_1991_Sp_Simpson.tei.xml
# Error with usc_1991_Sp_Sapper.tei.xml
# Error with usc_1991_Sp_Noyes.tei.xml
# Error with usc_1993_Sp_Alig.tei.xml
# Error with usc_1992_Sp_Thompson.tei.xml
# Error with usc_1991_Sp_Richardson.tei.xml
# Error with usc_1991_Sp_Sullivan.tei.xml
# Error with usc_1992_Sp_Skracic.tei.xml
# Error with usc_1992_Sp_Polosajian.tei.xml
# Error with usc_1992_Sp_Lorimier.tei.xml
# Error with usc_1992_Sp_Hughes.tei.xml
# Error with usc_1992_Sp_Gampel.tei.xml
# Error with usc_1992_Sp_Herbelin.tei.xml
# Error with usc_1992_Sp_Goicoechea.tei.xml
# Error with usc_1993_Sp_Naim.tei.xml
# Error with usc_1993_Sp_Nguyen.tei.xml
# Error with usc_1993_Sp_Lo.tei.xml
# Error with usc_1993_Sp_Le.tei.xml
# Error with usc_1993_Sp_Mishra.tei.xml
# Error with usc_1993_Sp_Howard.tei.xml
# Error with usc_1993_Sp_House.tei.xml
# Error with usc_1993_Sp_Davis.tei.xml
# Error with usc_1993_Sp_Bierzychudek.tei.xml
# Error with usc_1994_Sp_Henry.tei.xml
# Error with usc_1994_Sp_Muche.tei.xml
# Error with usc_1994_Sp_Fabula.tei.xml
# Error with usc_1994_Sp_Didier.tei.xml
# Error with usc_1994_Sp_DeLorenzo.tei.xml
# Error with usc_1993_Sp_Sachdev.tei.xml
# Error with usc_1993_Sp_Mitrevski.tei.xml
# Error with usc_1993_Sp_Talicuran.tei.xml
# Error with usc_1993_Sp_Pomeroy.tei.xml
# Error with usc_1993_Sp_Peneguy.tei.xml
# Error with usc_1994_Sp_Petrossian.tei.xml
# Error with usc_1993_Sp_Pattengill.tei.xml
# Error with usc_1994_Sp_Moribe.tei.xml
# Error with usc_1994_Sp_Thompson.tei.xml
# Error with usc_1994_Sp_Ring.tei.xml
# Error with usc_1994_Sp_Nedved.tei.xml
# Error with usc_1994_Sp_Karo.tei.xml
# Error with usc_1998_Sp_Munoz.tei.xml
# Error with usc_1998_Sp_Kim.tei.xml
# Error with usc_1998_Sp_Carr.tei.xml
# Error with usc_1998_Sp_Betancourt.tei.xml
# Error with usc_1998_Sp_Perry.tei.xml
# Error with osu_20200612144309599.tei.xml
# Error with osu_20200612151908800.tei.xml
# Error with osu_20200612151817901.tei.xml
# Error with osu_20200612151706297.tei.xml
# Error with osu_20200612145128338.tei.xml
# Error with osu_20200612151445199.tei.xml
# Error with osu_20200612145442428.tei.xml
# Error with osu_20200612144837511.tei.xml
# Error with osu_20200612145031481.tei.xml
# Error with osu_20200612145300353.tei.xml
# Error with osu_20200612151609779.tei.xml
# Error with osu_20200612144745670.tei.xml
# Error with osu_20200612151530698.tei.xml
# Error with osu_20200612144428207.tei.xml
# Finished at 2021-03-16 16:36:40.370843, total time 0.0 minutes

# %%
fhl_paper1 = papers_tei/"fhl_2011_Bockmon_26635.tei.xml"
fhl_paper1 = papers_tei/"fhl_2011_Bockmon_26635.tei.xml"

# %%
records = etl.process_xml(fhl_paper1.read_bytes(), fhl_paper1.name, nlp)

# %%
records
# Out:
#                          Paper ID                                Instance ID  \
# 0  fhl_2011_Bockmon_26635.tei.xml  urn:lsid:marinespecies.org:taxname:603085
# 1  fhl_2011_Bockmon_26635.tei.xml  urn:lsid:marinespecies.org:taxname:112078
# 2  fhl_2011_Bockmon_26635.tei.xml  urn:lsid:marinespecies.org:taxname:112078
# 3  fhl_2011_Bockmon_26635.tei.xml  urn:lsid:marinespecies.org:taxname:112078
#
#      Species                                               GBIF Time  \
# 0  trossulus  https://www.gbif.org/species/search?q=trossulu...
# 1    ammonia  https://www.gbif.org/species/search?q=ammonia&...
# 2    Ammonia  https://www.gbif.org/species/search?q=Ammonia&...
# 3    ammonia  https://www.gbif.org/species/search?q=ammonia&...
#
#             Place Habitats  div_enum
# 0  north end,tide                  3
# 1                                 11
# 2                                 11
# 3                                 12

# %%
from pandas.io.clipboard import copy; copy("\x04")
